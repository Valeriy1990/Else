# %% [markdown]
# <a href="https://colab.research.google.com/github/Valeriy1990/Else/blob/main/21_3_%D0%A1%D1%80%D0%B0%D0%B2%D0%BD%D0%B5%D0%BD%D0%B8%D0%B5_%D0%B0%D1%80%D1%85%D0%B8%D1%82%D0%B5%D0%BA%D1%82%D1%83%D1%80_%D1%80%D0%B5%D0%BA%D1%83%D1%80%D1%80%D0%B5%D0%BD%D1%82%D0%BD%D1%8B%D1%85_%D0%B8_%D0%BE%D0%B4%D0%BD%D0%BE%D0%BC%D0%B5%D1%80%D0%BD%D1%8B%D1%85_%D1%81%D0%B2%D0%B5%D1%80%D1%82%D0%BE%D1%87%D0%BD%D1%8B%D1%85_%D1%81%D0%B5%D1%82%D0%B5%D0%B9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![Новая презентация - 2025-04-02T002004.731.png](data:image/png;base64,...)

# %% [markdown]
# **Навигация по уроку**
#
# 1. [Рекуррентные нейронные сети](https://colab.research.google.com/drive/1Mm5yFeJXZT9YcwlQMGx_T5JcEVgV8ZWy)
# 2. [Одномерные сверточные нейронные сети](https://colab.research.google.com/drive/1SCmcJdfsaxpJiQz_SOMH6gixV-43zPIB)
# 3. Сравнение архитектур рекуррентных и одномерных сверточных сетей
# 4. [Домашняя работа](https://colab.research.google.com/drive/1NMDG3ZeGgyHm0ei0DOC63PBb9rW6oN3O)

# %% [markdown]
# Теперь мы можем перейти к практической части урока по рекуррентным и сверточным
# сетям. Мы продолжим решать уже знакомую задачу по классификации текстов русских писателей. Также продолжим использовать навыки Наташи для предобучения слоя `Embedding`. Однако, теперь мы проведем исследование различных архитектур, как настоящие нейронщики, выберем наиболее эффективные слои из рекурентных или одномерных сверточных, а также подберем параметры.

# %% [markdown]
# ## Обработка художественных текстов рекуррентными и сверточными сетями

# %% [markdown]
# ### Импортируем необходимые модули

# %%
from keras.models import Sequential
from keras.utils import get_file, to_categorical
from keras.layers import Embedding, Flatten, Dense, SpatialDropout1D, BatchNormalization, Dropout, SimpleRNN
from keras.layers import GRU, LSTM, Bidirectional, Conv1D, MaxPooling1D, GlobalMaxPooling1D

from tensorflow.keras.preprocessing.text import Tokenizer

import os   # Модуль для работы с файловой системой

import glob # Вспомогательный модуль для работы с файловой системой
import numpy as np

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay # Для работы с матрицей ошибок

import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Мы подгружаем новые для вас слои – **SimpleRNN**, **GRU**, **LSTM**,  **SpatialDropout1D**, **Bidirectional**, **Conv1D**, **MaxPooling1D**, **GlobalMaxPooling1D**.
#
# У **MaxPooling1D** и **GlobalMaxPooling1D** логика работы одинаковая, отличается только в размере окна прохождения. Пусть у нас имеется тензор `[1, 4, 8, 4, 5, 2]` и размер окна 2. При прохождениим  MaxPooling1D получим тензор `[4, 8, 5]`, так как берет максимум в окне. GlobalMaxPooling1D выдаст `[8]`, так как его окно всегда равняется максимально возможному размеру тензора.
#
# **SpatialDropout1D** используется после слоя **Embedding** в случае, если после слоя **Embedding** нужно применить слой **Dropout**. Это вызвано тем, что слой **Embedding** разворачивает слова в таблицу с тензорами определенной длины. И **Dropout**-слой будет выкидывать значения из тензоров, что нарушит логику работы. Слой **SpatialDropout1D** выкидывает целый тензор, что и требуется.
#
# Например, у нас имеется тензор $[[1, 1, 1], [2, 2, 2], [3, 3, 3]]$. Если мы к нему применем **Dropout**, то получим что-то вида $[[1, 0, 1], [0, 2, 2], [[3,0, 3]]]$, где значения обнулены в случайном порядке. Если пропустим тензор через **SpatialDropout1D**, то получим $[[1, 0, 1], [2, 0, 2], [3, 0, 3]]$. Мы видим, что был очищен случайный столбец целиком. Таким образом при обрабоке текстов, **SpatialDropout1D** будет убирать вектор слова целиком.
#
# При создании рекуррентного слоя **SimpleRNN**, **GRU**, **LSTM** всегда указывается размерность скрытого состояния units как именованный параметр:
#
# ```python
# units    = 4          # размерность скрытого состояния
# model = Sequential()
# ...
# model.add(SimpleRNN(units=units))
# ```
# или как позиционный параметр:
#
# ```python
# model.add(SimpleRNN(4))
# ```
# В примерах ниже мы будем использовать функции активации для рекуррентных слоев и параметры регуляризации. Так например:
#
# `GRU(4, dropout=0.2, recurrent_dropout=0.2, activation='relu')` – используем для слоя GRU четыре нейрона, `dropout=0.2` – дропаут 20% на входные данные и `recurrent_dropout=0.2` – дропаут 20% на данные, которые возвращаются обратно, обработанные нейроном.
#
# При необходимости можно вернуть еще и промежуточные выходы (скрытые состояния) каждой ячейки на всех итерациях: $h_0, ..., h_n$. Для этого в рекуррентном слое устанавливаем параметр `return_sequences=True`.
#
# Можно дополнительно вернуть еще и внутренние состояния ячеек на всех итерациях, установив парамтр `return_state=True`.
#
# По умолчанию `return_sequences=False` и `return_state=False`.

# %% [markdown]
# ### Загрузка предобученных Embedding

# %%
# !wget https://storage.yandexcloud.net/natasha-navec/packs/navec_hudlit_v1_12B_500K_300d_100q.tar
# Out:
# --2024-03-12 19:12:19--  https://storage.yandexcloud.net/natasha-navec/packs/navec_hudlit_v1_12B_500K_300d_100q.tar
# Resolving storage.yandexcloud.net (storage.yandexcloud.net)... 213.180.193.243, 2a02:6b8::1d9
# Connecting to storage.yandexcloud.net (storage.yandexcloud.net)|213.180.193.243|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 53012480 (51M) [application/x-tar]
# Saving to: ‘navec_hudlit_v1_12B_500K_300d_100q.tar’
#
# navec_hudlit_v1_12B 100%[===================>]  50.56M  16.1MB/s    in 3.4s
#
# 2024-03-12 19:12:24 (14.8 MB/s) - ‘navec_hudlit_v1_12B_500K_300d_100q.tar’ saved [53012480/53012480]

# %%
# !pip install navec
# Out:
# Collecting navec
#   Downloading navec-0.10.0-py3-none-any.whl (23 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from navec) (1.25.2)
# Installing collected packages: navec
# Successfully installed navec-0.10.0

# %%
from navec import Navec
navec = Navec.load('navec_hudlit_v1_12B_500K_300d_100q.tar')

# %% [markdown]
# ### Подготовка датасета

# %% [markdown]
# Повторим шаги из прошлого урока:

# %% [markdown]
# **Шаг 1. Загрузка базы писателей Русской литературы**

# %%
data_path = get_file(
    "russian_literature.zip",
    "https://storage.yandexcloud.net/academy.ai/russian_literature.zip"
)
# Out:
# Downloading data from https://storage.yandexcloud.net/academy.ai/russian_literature.zip
# 21547079/21547079 [==============================] - 2s 0us/step

# %% [markdown]
# **Шаг 2. Распаковка датасета**

# %%
# Разархивируем датасета во временную папку 'dataset'
# !unzip -qo "{data_path}" -d ./dataset

# %% [markdown]
# **Шаг 3. Формирование датасета**

# %% [markdown]
# Сформируем список всех писателей.

# %%
FILE_DIR_POEMS = './dataset/poems'
file_list_poems = os.listdir(FILE_DIR_POEMS)
print("Поэты:")
print(file_list_poems)
# Out:
# Поэты:
# ['Nekrasov', 'Blok', 'Pushkin', 'Lermontov']

# %%
FILE_DIR_PROSE = './dataset/prose'
file_list_prose = os.listdir(FILE_DIR_PROSE)
print("Прозаики:")
print(file_list_prose)
# Out:
# Прозаики:
# ['Turgenev', 'Gogol', 'Chekhov', 'Blok', 'Tolstoy', 'Herzen', 'Pushkin', 'Dostoevsky', 'Lermontov', 'Gorky', 'Bryusov']

# %% [markdown]
# Объединим списки и избавимся от дублей. Для этого с помощью операции сложения (конкатенации) списков объединим списки. Затем преобразуем их в множества (вспомним, что множества содержат только уникальные значения). И после снова преобразуем в список:

# %%
CLASS_LIST = list(set(file_list_poems + file_list_prose))
print("Общий список писателей:")
print(CLASS_LIST)
# Out:
# Общий список писателей:
# ['Blok', 'Nekrasov', 'Chekhov', 'Pushkin', 'Tolstoy', 'Lermontov', 'Gogol', 'Turgenev', 'Dostoevsky', 'Bryusov', 'Herzen', 'Gorky']

# %%
all_texts = {} # Собираем в словарь весь датасет

for author in CLASS_LIST:
    all_texts[author] = '' # Инициализируем пустой строкой новый ключ словаря
    for path in glob.glob('./dataset/prose/{}/*.txt'.format(author)) +  glob.glob('./dataset/poems/{}/*.txt'.format(author)): # Поиск файлов по шаблону
        with open(f'{path}', 'r', errors='ignore') as f: # игнорируем ошибки (например символы из другой кодировки)
            # Загрузка содержимого файла в строку
            text = f.read()

        all_texts[author]  += ' ' + text.replace('\n', ' ') # Заменяем символ перехода на новую строку пробелом

# %% [markdown]
# **Шаг 4. Токенизация**

# %%
embedding_dim = 300    # размерность векторов эмбединга (300d в имени эмбединга)
max_words = 15000      # Количество слов, рассматриваемых как признаки

# Используется встроенный в Keras токенизатор для разбиения текста и построения частотного словаря
tokenizer = Tokenizer(num_words=max_words,
                      filters='!"#$%&()*+,-–—./…:;<=>?@[\\]^_`{|}~«»\t\n\xa0\ufeff',
                      lower=True, split=' ', char_level=False)


# Построение частотного словаря по текстам
tokenizer.fit_on_texts(all_texts.values())

# %% [markdown]
# Обратите внимание, что мы увеличили колчество слов `max_words` до 15000. Это стало возможно, так как архитектуры на рекуррентных и одномерных свертках потребляют меньше оперативной памяти, чем полносвязные слои. Что потенциально должно увеличить точность классификации.

# %% [markdown]
# **Шаг 5. Преобразование текста в последовательность**

# %% [markdown]
# Преобразуем текст в последовательности:

# %%
seq_train = tokenizer.texts_to_sequences(all_texts.values())

# %% [markdown]
# **Шаг 6. Балансировка датасета**

# %% [markdown]
# Для того, чтобы мы могли наглядно сравнить архитектуры рекурентных, одномерных сверток с полносвязанными слоями (из урока [20.2](https://colab.research.google.com/drive/1KEFUgyBcqGaXGZEU-7MHENn5RH_AIvfH)), мы должны взять аналогичные примеры для обучения, поэтому применим аналогичную балансировку с отсечкой писателей с небольшими текстами.

# %%
# используем генератор цикла для получения длины текстов по каждому автору
total = sum(len(i) for i in seq_train)
print(f'Датасет состоит из {total} слов')

print('Общая выборка по писателям (по словам):')
mean_list = np.array([])
for author in CLASS_LIST:
    cls = CLASS_LIST.index(author)
    print(f'{author} - {len(seq_train[cls])} слов, доля в общей базе: {len(seq_train[cls])/total*100 :.2f}%')
    mean_list = np.append(mean_list, len(seq_train[cls]))

print('Среднее значение слов: ', np.round(mean_list.mean()))
print('Медианное значение слов: ', np.median(mean_list))


median = int(np.median(mean_list)) # Зафиксировали медианное значение
CLASS_LIST_BALANCE = [] # Сбалансированный набор меток
seq_train_balance = []
for author in CLASS_LIST:
    cls = CLASS_LIST.index(author)
    if len(seq_train[cls]) > median * 0.6:
      seq_train_balance.append(seq_train[cls][:median])
      CLASS_LIST_BALANCE.append(author)
# Out:
# Датасет состоит из 4990033 слов
# Общая выборка по писателям (по словам):
# Blok - 65511 слов, доля в общей базе: 1.31%
# Nekrasov - 39227 слов, доля в общей базе: 0.79%
# Chekhov - 244769 слов, доля в общей базе: 4.91%
# Pushkin - 168335 слов, доля в общей базе: 3.37%
# Tolstoy - 1237104 слов, доля в общей базе: 24.79%
# Lermontov - 46916 слов, доля в общей базе: 0.94%
# Gogol - 277488 слов, доля в общей базе: 5.56%
# Turgenev - 305451 слов, доля в общей базе: 6.12%
# Dostoevsky - 1548617 слов, доля в общей базе: 31.03%
# Bryusov - 349263 слов, доля в общей базе: 7.00%
# Herzen - 153340 слов, доля в общей базе: 3.07%
# Gorky - 554012 слов, доля в общей базе: 11.10%
# Среднее значение слов:  415836.0
# Медианное значение слов:  261128.5

# %%
total = sum(len(i) for i in seq_train_balance)

print('Сбалансированная выборка по писателям (по словам):')
mean_list_balance = np.array([])
for author in CLASS_LIST_BALANCE:
    cls = CLASS_LIST_BALANCE.index(author)
    print(f'{author} - {len(seq_train_balance[cls])} слов, доля в общей базе: {len(seq_train_balance[cls])/total*100 :.2f}%')
    mean_list_balance = np.append(mean_list_balance, len(seq_train_balance[cls]))

print('Среднее значение слов: ', np.round(mean_list_balance.mean()))
print('Медианное значение слов: ', np.median(mean_list_balance))
# Out:
# Сбалансированная выборка по писателям (по словам):
# Chekhov - 244769 слов, доля в общей базе: 12.36%
# Pushkin - 168335 слов, доля в общей базе: 8.50%
# Tolstoy - 261128 слов, доля в общей базе: 13.19%
# Gogol - 261128 слов, доля в общей базе: 13.19%
# Turgenev - 261128 слов, доля в общей базе: 13.19%
# Dostoevsky - 261128 слов, доля в общей базе: 13.19%
# Bryusov - 261128 слов, доля в общей базе: 13.19%
# Gorky - 261128 слов, доля в общей базе: 13.19%
# Среднее значение слов:  247484.0
# Медианное значение слов:  261128.0

# %%
fig, ax = plt.subplots()
ax.pie([len(i) for i in seq_train_balance],  # формируем список значений как длина символов текста каждого автора
       labels=CLASS_LIST_BALANCE,            # список меток
       pctdistance=1.2,                      # дистанция размещения % (1 - граница окружности)
       labeldistance=1.4,                    # размещение меток (1 - граница окружности)
       autopct='%1.2f%%'                     # формат для % (2 знака после запятой)
      )
plt.show()

# %%
# используем генератор цикла для получения длины текстов по каждому автору
total = sum(len(i) for i in seq_train_balance)
print(f'Датасет состоит из {total} слов')
# Out:
# Датасет состоит из 1979872 слов

# %%
print('Общая выборка по писателям (по словам):')
mean_list = np.array([])
for author in CLASS_LIST_BALANCE:
    cls = CLASS_LIST_BALANCE.index(author)
    print(f'{author} - {len(seq_train_balance[cls])} слов, доля в общей базе: {len(seq_train_balance[cls])/total*100 :.2f}%')
    mean_list = np.append(mean_list, len(seq_train_balance[cls]))

print('Среднее значение слов: ', np.round(mean_list.mean()))
print('Медианное значение слов: ', np.median(mean_list))
# Out:
# Общая выборка по писателям (по словам):
# Chekhov - 244769 слов, доля в общей базе: 12.36%
# Pushkin - 168335 слов, доля в общей базе: 8.50%
# Tolstoy - 261128 слов, доля в общей базе: 13.19%
# Gogol - 261128 слов, доля в общей базе: 13.19%
# Turgenev - 261128 слов, доля в общей базе: 13.19%
# Dostoevsky - 261128 слов, доля в общей базе: 13.19%
# Bryusov - 261128 слов, доля в общей базе: 13.19%
# Gorky - 261128 слов, доля в общей базе: 13.19%
# Среднее значение слов:  247484.0
# Медианное значение слов:  261128.0

# %%
fig, ax = plt.subplots()
ax.pie([len(i) for i in seq_train_balance], # формируем список значений как длина символов текста каждого автора
       labels=CLASS_LIST_BALANCE,                    # список меток
       pctdistance=1.2,                      # дистанция размещения % (1 - граница окружности)
       labeldistance=1.4,                    # размещение меток (1 - граница окружности)
       autopct='%1.2f%%'                     # формат для % (2 знака после запятой)
      )
plt.show()

# %% [markdown]
# **Шаг 7. Нарезка примеров из текста методом скользящего окна**

# %%
WIN_SIZE = 1000   # Ширина окна в токенах
WIN_STEP = 100    # Шаг окна в токенах

# Функция разбиения последовательности на отрезки скользящим окном
# Последовательность разбивается на части до последнего полного окна
# Параметры:
# sequence - последовательность токенов
# win_size - размер окна
# step - шаг окна
def seq_split(sequence, win_size, step):
    # Делим строку на отрезки с помощью генератора цикла
    return [sequence[i:i + win_size] for i in range(0, len(sequence) - win_size + 1, step)]

def seq_vectorize(
    seq_list,   # Последовательность
    test_split, # Доля на тестовую выборку
    class_list, # Список классов
    win_size,   # Ширина скользящего окна
    step        # Шаг скользящего окна
):

    # Списки для результирующих данных
    x_train, y_train, x_test, y_test =  [], [], [], []

    # Пробежимся по всем классам:
    for class_item in class_list:
        # Получим индекс класса
        cls = class_list.index(class_item)

        # Пороговое значение индекса для разбивки на тестовую и обучающую выборки
        gate_split = int(len(seq_list[cls]) * (1-test_split))

        # Разбиваем последовательность токенов класса на отрезки
        vectors_train = seq_split(seq_list[cls][:gate_split], win_size, step) # последовательность до порога попадет в обучающую выборку
        vectors_test = seq_split(seq_list[cls][gate_split:], win_size, step)  # последовательность после порога попадет в тестовую выборку

        # Добавляем отрезки в выборку
        x_train += vectors_train
        x_test += vectors_test

        # Для всех отрезков класса добавляем метки класса в виде one-hot-encoding
        # Каждую метку берем len(vectors) раз, так она одинакова для всех выборок одного класса
        y_train += [to_categorical(cls, len(class_list))] * len(vectors_train)
        y_test += [to_categorical(cls, len(class_list))] * len(vectors_test)

    # Возвращаем результатов как numpy-массивов
    return np.array(x_train), np.array(y_train), np.array(x_test), np.array(y_test)

# %%
x_train, y_train, x_test, y_test = seq_vectorize(seq_train_balance, 0.1, CLASS_LIST_BALANCE, WIN_SIZE, WIN_STEP)

# %%
print(f'Форма входных данных для обучающей выборки: {x_train.shape}')
print(f'Форма выходных данных (меток) для обучающей выборки: {y_train.shape}')
# Out:
# Форма входных данных для обучающей выборки: (17745, 1000)
# Форма выходных данных (меток) для обучающей выборки: (17745, 8)

# %%
print(f'Форма входных данных для тестовой выборки: {x_test.shape}')
print(f'Форма выходных данных (меток) для тестовой выборки: {y_test.shape}')
# Out:
# Форма входных данных для тестовой выборки: (1906, 1000)
# Форма выходных данных (меток) для тестовой выборки: (1906, 8)

# %% [markdown]
# **Шаг 8. Определим вспомагательные функции**

# %%
# Вывод графиков точности и ошибки
def show_plot(history, title=''):
    fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 5))
    fig.suptitle('График процесса обучения модели: '+title)
    ax1.plot(history.history['accuracy'],
               label='График точности на обучающей выборке')
    ax1.plot(history.history['val_accuracy'],
               label='График точности на проверочной выборке')
    ax1.xaxis.get_major_locator().set_params(integer=True) # На оси х показываем целые числа
    ax1.set_xlabel('Эпоха обучения')
    ax1.set_ylabel('График точности')
    ax1.legend()

    ax2.plot(history.history['loss'],
               label='Ошибка на обучающей выборке')
    ax2.plot(history.history['val_loss'],
               label='Ошибка на проверочной выборке')
    ax2.xaxis.get_major_locator().set_params(integer=True) # На оси х показываем целые числа
    ax2.set_xlabel('Эпоха обучения')
    ax2.set_ylabel('Ошибка')
    ax2.legend()
    plt.show()

# Функция вывода предсказанных значений
def show_confusion_matrix(y_true, y_pred, class_labels):
    # Матрица ошибок
    cm = confusion_matrix(np.argmax(y_true, axis=1),
                          np.argmax(y_pred, axis=1),
                          normalize='true')
    # Округление значений матрицы ошибок
    cm = np.around(cm, 3)

    # Отрисовка матрицы ошибок
    fig, ax = plt.subplots(figsize=(10, 10))
    ax.set_title(f'Матрица ошибок', fontsize=18)
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=class_labels)
    disp.plot(ax=ax)
    plt.gca().images[-1].colorbar.remove()  # Убираем ненужную цветовую шкалу
    plt.xlabel('Предсказанные классы', fontsize=16)
    plt.ylabel('Верные классы', fontsize=16)
    fig.autofmt_xdate(rotation=45)          # Наклон меток горизонтальной оси
    plt.show()


    # Средняя точность распознавания определяется как среднее диагональных элементов матрицы ошибок
    print('\nСредняя точность распознавания: {:3.0f}%'.format(100. * cm.diagonal().mean()))

# %% [markdown]
# Также определим функцию загрузки в модель весов Наташи для Embedding:

# %%
def loadEmbedding():
    word_index = tokenizer.word_index
    embeddings_index = navec

    embedding_matrix = np.zeros((max_words, embedding_dim))
    for word, i in word_index.items():
        if i < max_words:
            embedding_vector = embeddings_index.get(word)
            if embedding_vector is not None:
                embedding_matrix[i] = embedding_vector

    return embedding_matrix

# %% [markdown]
# ### Сравнение архитектур сети

# %% [markdown]
# Так как мы используем предварительно сформированные векторные представления, то это накладывает ограничения на размерность входного слоя `Embedding` нашей модели (смотрим по имени файла navec_hudlit_v1_12B_500K_**300d**_100q.tar). Поэтому во всех наших экспериментах мы будем использовать один и тот же обученный входной слой `Embedding`.

# %% [markdown]
# #### **Embedding(Natasha) + SimpleRNN(10) + Dropout(0.3)**

# %%
# Создание последовательной модели нейросети
model_SimpleRNN_1 = Sequential()

# С помощью параметра weights передадим веса Наташи в модель
model_SimpleRNN_1.add(Embedding(max_words, embedding_dim, input_length=WIN_SIZE, weights=loadEmbedding()))

# Слой регуляризации, "выключает" 1D карты объектов из эмбеддинг-векторов
model_SimpleRNN_1.add(SpatialDropout1D(0.3))
# Слой нормализации данных
model_SimpleRNN_1.add(BatchNormalization())
# Рекуррентный слой
model_SimpleRNN_1.add(SimpleRNN(10))
# Слой регуляризации Dropout для отдельных нейронов
model_SimpleRNN_1.add(Dropout(0.3))
# Выходной слой классификатора
model_SimpleRNN_1.add(Dense(len(CLASS_LIST_BALANCE), activation='softmax'))

# %%
# Слой с весами Наташи мы обучать не будем, чтобы его не затереть
model_SimpleRNN_1.layers[0].trainable = False

# %%
model_SimpleRNN_1.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history = model_SimpleRNN_1.fit(x_train, y_train, epochs=50, batch_size=128, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 139/139 [==============================] - 122s 840ms/step - loss: 2.3025 - accuracy: 0.1338 - val_loss: 2.1257 - val_accuracy: 0.1322
# Epoch 2/50
# 139/139 [==============================] - 119s 858ms/step - loss: 2.1571 - accuracy: 0.1559 - val_loss: 2.0947 - val_accuracy: 0.1474
# Epoch 3/50
# 139/139 [==============================] - 119s 860ms/step - loss: 2.0928 - accuracy: 0.1641 - val_loss: 2.0765 - val_accuracy: 0.1527
# Epoch 4/50
# 139/139 [==============================] - 118s 852ms/step - loss: 2.0652 - accuracy: 0.1704 - val_loss: 2.0693 - val_accuracy: 0.1522
# Epoch 5/50
# 139/139 [==============================] - 115s 821ms/step - loss: 2.0453 - accuracy: 0.1779 - val_loss: 2.0687 - val_accuracy: 0.1501
# Epoch 6/50
# 139/139 [==============================] - 117s 841ms/step - loss: 2.0296 - accuracy: 0.1931 - val_loss: 2.0670 - val_accuracy: 0.1553
# Epoch 7/50
# 139/139 [==============================] - 115s 829ms/step - loss: 2.0143 - accuracy: 0.1947 - val_loss: 2.0717 - val_accuracy: 0.1621
# Epoch 8/50
# 139/139 [==============================] - 118s 853ms/step - loss: 1.9976 - accuracy: 0.2121 - val_loss: 2.0624 - val_accuracy: 0.1700
# Epoch 9/50
# 139/139 [==============================] - 116s 837ms/step - loss: 1.9945 - accuracy: 0.2144 - val_loss: 2.0336 - val_accuracy: 0.1737
# Epoch 10/50
# 139/139 [==============================] - 119s 853ms/step - loss: 2.0056 - accuracy: 0.2105 - val_loss: 2.0248 - val_accuracy: 0.1894
# Epoch 11/50
# 139/139 [==============================] - 119s 857ms/step - loss: 2.0056 - accuracy: 0.2057 - val_loss: 2.0716 - val_accuracy: 0.1558
# Epoch 12/50
# 139/139 [==============================] - 119s 856ms/step - loss: 1.9965 - accuracy: 0.2132 - val_loss: 2.0658 - val_accuracy: 0.1621
# Epoch 13/50
# 139/139 [==============================] - 116s 835ms/step - loss: 1.9927 - accuracy: 0.2168 - val_loss: 2.0592 - val_accuracy: 0.1637
# Epoch 14/50
# 139/139 [==============================] - 129s 926ms/step - loss: 1.9846 - accuracy: 0.2192 - val_loss: 2.0409 - val_accuracy: 0.1731
# Epoch 15/50
# 139/139 [==============================] - 119s 855ms/step - loss: 1.9838 - accuracy: 0.2242 - val_loss: 2.0509 - val_accuracy: 0.1726
# Epoch 16/50
# 139/139 [==============================] - 117s 843ms/step - loss: 1.9816 - accuracy: 0.2272 - val_loss: 2.0507 - val_accuracy: 0.1684
# Epoch 17/50
# 139/139 [==============================] - 117s 841ms/step - loss: 1.9844 - accuracy: 0.2240 - val_loss: 2.0635 - val_accuracy: 0.1642
# Epoch 18/50
# 139/139 [==============================] - 118s 848ms/step - loss: 1.9976 - accuracy: 0.2149 - val_loss: 2.0625 - val_accuracy: 0.1668
# Epoch 19/50
# 139/139 [==============================] - 115s 831ms/step - loss: 1.9955 - accuracy: 0.2164 - val_loss: 2.0647 - val_accuracy: 0.1605
# Epoch 20/50
# 139/139 [==============================] - 116s 839ms/step - loss: 1.9939 - accuracy: 0.2169 - val_loss: 2.0702 - val_accuracy: 0.1590
# Epoch 21/50
# 139/139 [==============================] - 116s 835ms/step - loss: 1.9889 - accuracy: 0.2206 - val_loss: 2.0597 - val_accuracy: 0.1658
# Epoch 22/50
# 139/139 [==============================] - 116s 834ms/step - loss: 1.9903 - accuracy: 0.2203 - val_loss: 2.0323 - val_accuracy: 0.1852
# Epoch 23/50
# 139/139 [==============================] - 117s 841ms/step - loss: 1.9829 - accuracy: 0.2286 - val_loss: 2.0314 - val_accuracy: 0.1894
# Epoch 24/50
# 139/139 [==============================] - 117s 835ms/step - loss: 1.9835 - accuracy: 0.2238 - val_loss: 2.0309 - val_accuracy: 0.1873
# Epoch 25/50
# 139/139 [==============================] - 115s 825ms/step - loss: 1.9876 - accuracy: 0.2213 - val_loss: 2.0393 - val_accuracy: 0.1794
# Epoch 26/50
# 139/139 [==============================] - 115s 830ms/step - loss: 1.9792 - accuracy: 0.2255 - val_loss: 2.0551 - val_accuracy: 0.1800
# Epoch 27/50
# 139/139 [==============================] - 116s 835ms/step - loss: 2.0115 - accuracy: 0.2068 - val_loss: 2.0447 - val_accuracy: 0.1847
# Epoch 28/50
# 139/139 [==============================] - 115s 826ms/step - loss: 1.9915 - accuracy: 0.2205 - val_loss: 2.0431 - val_accuracy: 0.1831
# Epoch 29/50
# 139/139 [==============================] - 115s 830ms/step - loss: 1.9888 - accuracy: 0.2218 - val_loss: 2.0385 - val_accuracy: 0.1758
# Epoch 30/50
# 139/139 [==============================] - 117s 840ms/step - loss: 1.9768 - accuracy: 0.2326 - val_loss: 2.0350 - val_accuracy: 0.1894
# Epoch 31/50
# 139/139 [==============================] - 116s 836ms/step - loss: 1.9927 - accuracy: 0.2217 - val_loss: 2.0140 - val_accuracy: 0.2041
# Epoch 32/50
# 139/139 [==============================] - 115s 831ms/step - loss: 1.9857 - accuracy: 0.2245 - val_loss: 2.0209 - val_accuracy: 0.1957
# Epoch 33/50
# 139/139 [==============================] - 116s 835ms/step - loss: 1.9779 - accuracy: 0.2286 - val_loss: 2.0488 - val_accuracy: 0.1826
# Epoch 34/50
# 139/139 [==============================] - 120s 868ms/step - loss: 1.9747 - accuracy: 0.2289 - val_loss: 2.0255 - val_accuracy: 0.1952
# Epoch 35/50
# 139/139 [==============================] - 119s 858ms/step - loss: 1.9742 - accuracy: 0.2314 - val_loss: 2.0659 - val_accuracy: 0.1805
# Epoch 36/50
#  13/139 [=>............................] - ETA: 1:40 - loss: 1.9849 - accuracy: 0.2350

# %%
show_plot(history, 'Embedding(Natasha) + SimpleRNN(10) + Dropout(0.3)')

# %%
y_pred = model_SimpleRNN_1.predict(x_test)
show_confusion_matrix(y_test, y_pred, CLASS_LIST_BALANCE)
# Out:
# 60/60 [==============================] - 5s 75ms/step
# Средняя точность распознавания:  19%

# %% [markdown]
# #### **Embedding(Natasha) + SimpleRNN(5) + Dropout(0.2)**

# %%
# Создание последовательной модели нейросети
model_SimpleRNN_2 = Sequential()

model_SimpleRNN_2.add(Embedding(max_words, embedding_dim, input_length=WIN_SIZE, weights=loadEmbedding()))

# Слой регуляризации, "выключает" 1D карты объектов из эмбеддинг-векторов
model_SimpleRNN_2.add(SpatialDropout1D(0.2))
# Слой нормализации данных
model_SimpleRNN_2.add(BatchNormalization())
# Рекуррентный слой
model_SimpleRNN_2.add(SimpleRNN(5))
# Слой регуляризации Dropout для отдельных нейронов
model_SimpleRNN_2.add(Dropout(0.2))
# Выходной слой классификатора
model_SimpleRNN_2.add(Dense(len(CLASS_LIST_BALANCE), activation='softmax'))

# %%
model_SimpleRNN_2.layers[0].trainable = False

# %%
model_SimpleRNN_2.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history2 = model_SimpleRNN_2.fit(x_train, y_train, epochs=50, batch_size=128, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 139/139 [==============================] - 129s 887ms/step - loss: 2.2046 - accuracy: 0.1348 - val_loss: 2.1133 - val_accuracy: 0.1280
# Epoch 2/50
# 139/139 [==============================] - 121s 873ms/step - loss: 2.1141 - accuracy: 0.1514 - val_loss: 2.0927 - val_accuracy: 0.1432
# Epoch 3/50
# 139/139 [==============================] - 121s 872ms/step - loss: 2.0764 - accuracy: 0.1590 - val_loss: 2.0773 - val_accuracy: 0.1542
# Epoch 4/50
# 139/139 [==============================] - 121s 867ms/step - loss: 2.0572 - accuracy: 0.1715 - val_loss: 2.0712 - val_accuracy: 0.1480
# Epoch 5/50
# 139/139 [==============================] - 120s 861ms/step - loss: 2.0413 - accuracy: 0.1836 - val_loss: 2.0690 - val_accuracy: 0.1448
# Epoch 6/50
# 139/139 [==============================] - 121s 864ms/step - loss: 2.0301 - accuracy: 0.1890 - val_loss: 2.0696 - val_accuracy: 0.1490
# Epoch 7/50
# 139/139 [==============================] - 121s 869ms/step - loss: 2.0194 - accuracy: 0.1993 - val_loss: 2.0657 - val_accuracy: 0.1605
# Epoch 8/50
# 139/139 [==============================] - 120s 863ms/step - loss: 2.0024 - accuracy: 0.2087 - val_loss: 2.0682 - val_accuracy: 0.1689
# Epoch 9/50
# 139/139 [==============================] - 118s 852ms/step - loss: 1.9993 - accuracy: 0.2131 - val_loss: 2.0715 - val_accuracy: 0.1637
# Epoch 10/50
# 139/139 [==============================] - 120s 866ms/step - loss: 1.9847 - accuracy: 0.2225 - val_loss: 2.0563 - val_accuracy: 0.1689
# Epoch 11/50
# 139/139 [==============================] - 121s 870ms/step - loss: 1.9890 - accuracy: 0.2185 - val_loss: 2.0651 - val_accuracy: 0.1794
# Epoch 12/50
# 139/139 [==============================] - 121s 870ms/step - loss: 1.9869 - accuracy: 0.2215 - val_loss: 2.0777 - val_accuracy: 0.1758
# Epoch 13/50
# 139/139 [==============================] - 119s 858ms/step - loss: 2.0161 - accuracy: 0.2079 - val_loss: 2.0398 - val_accuracy: 0.1831
# Epoch 14/50
# 139/139 [==============================] - 121s 870ms/step - loss: 1.9926 - accuracy: 0.2241 - val_loss: 2.0375 - val_accuracy: 0.1878
# Epoch 15/50
# 139/139 [==============================] - 119s 854ms/step - loss: 1.9794 - accuracy: 0.2313 - val_loss: 2.0456 - val_accuracy: 0.1857
# Epoch 16/50
# 139/139 [==============================] - 120s 860ms/step - loss: 1.9723 - accuracy: 0.2333 - val_loss: 2.0354 - val_accuracy: 0.1999
# Epoch 17/50
# 139/139 [==============================] - 120s 857ms/step - loss: 1.9682 - accuracy: 0.2332 - val_loss: 2.0298 - val_accuracy: 0.2051
# Epoch 18/50
# 139/139 [==============================] - 122s 874ms/step - loss: 1.9933 - accuracy: 0.2207 - val_loss: 2.0586 - val_accuracy: 0.1716
# Epoch 19/50
# 139/139 [==============================] - 122s 879ms/step - loss: 2.0321 - accuracy: 0.1848 - val_loss: 2.0347 - val_accuracy: 0.1826
# Epoch 20/50
# 139/139 [==============================] - 121s 868ms/step - loss: 2.0239 - accuracy: 0.1893 - val_loss: 2.0416 - val_accuracy: 0.1805
# Epoch 21/50
# 139/139 [==============================] - 121s 870ms/step - loss: 2.0217 - accuracy: 0.1862 - val_loss: 2.0307 - val_accuracy: 0.1763
# Epoch 22/50
# 139/139 [==============================] - 118s 851ms/step - loss: 2.0108 - accuracy: 0.1927 - val_loss: 2.0307 - val_accuracy: 0.1731
# Epoch 23/50
# 139/139 [==============================] - 119s 860ms/step - loss: 2.0121 - accuracy: 0.1934 - val_loss: 2.0415 - val_accuracy: 0.1779
# Epoch 24/50
# 139/139 [==============================] - 121s 874ms/step - loss: 2.0075 - accuracy: 0.1985 - val_loss: 2.0356 - val_accuracy: 0.1889
# Epoch 25/50
# 139/139 [==============================] - 123s 885ms/step - loss: 2.0029 - accuracy: 0.2022 - val_loss: 2.0378 - val_accuracy: 0.1821
# Epoch 26/50
# 139/139 [==============================] - 119s 859ms/step - loss: 2.0034 - accuracy: 0.1946 - val_loss: 2.0469 - val_accuracy: 0.1695
# Epoch 27/50
# 139/139 [==============================] - 120s 860ms/step - loss: 2.0013 - accuracy: 0.1961 - val_loss: 2.0459 - val_accuracy: 0.1695
# Epoch 28/50
# 139/139 [==============================] - 121s 873ms/step - loss: 1.9983 - accuracy: 0.2024 - val_loss: 2.0354 - val_accuracy: 0.1768
# Epoch 29/50
# 139/139 [==============================] - 120s 865ms/step - loss: 2.0086 - accuracy: 0.1941 - val_loss: 2.0271 - val_accuracy: 0.1973
# Epoch 30/50
# 139/139 [==============================] - 120s 865ms/step - loss: 2.0035 - accuracy: 0.2005 - val_loss: 2.0239 - val_accuracy: 0.1988
# Epoch 31/50
# 139/139 [==============================] - 121s 870ms/step - loss: 2.0010 - accuracy: 0.2011 - val_loss: 2.0206 - val_accuracy: 0.2083
# Epoch 32/50
# 139/139 [==============================] - 121s 874ms/step - loss: 1.9945 - accuracy: 0.2087 - val_loss: 2.0264 - val_accuracy: 0.1878
# Epoch 33/50
# 139/139 [==============================] - 122s 878ms/step - loss: 1.9855 - accuracy: 0.2085 - val_loss: 2.0292 - val_accuracy: 0.1905
# Epoch 34/50
# 139/139 [==============================] - 121s 872ms/step - loss: 1.9842 - accuracy: 0.2136 - val_loss: 2.0308 - val_accuracy: 0.1910
# Epoch 35/50
# 139/139 [==============================] - 123s 884ms/step - loss: 1.9860 - accuracy: 0.2087 - val_loss: 2.0250 - val_accuracy: 0.2009
# Epoch 36/50
# 139/139 [==============================] - 120s 862ms/step - loss: 1.9810 - accuracy: 0.2153 - val_loss: 2.0211 - val_accuracy: 0.2093
# Epoch 37/50
# 139/139 [==============================] - 120s 860ms/step - loss: 1.9771 - accuracy: 0.2220 - val_loss: 2.0268 - val_accuracy: 0.1999
# Epoch 38/50
# 139/139 [==============================] - 120s 867ms/step - loss: 1.9780 - accuracy: 0.2180 - val_loss: 2.0333 - val_accuracy: 0.1973
# Epoch 39/50
# 139/139 [==============================] - 122s 876ms/step - loss: 1.9711 - accuracy: 0.2308 - val_loss: 2.0351 - val_accuracy: 0.2072
# Epoch 40/50
# 139/139 [==============================] - 124s 896ms/step - loss: 1.9748 - accuracy: 0.2306 - val_loss: 2.0330 - val_accuracy: 0.2151
# Epoch 41/50
# 139/139 [==============================] - 121s 874ms/step - loss: 1.9710 - accuracy: 0.2305 - val_loss: 2.0180 - val_accuracy: 0.2177
# Epoch 42/50
# 139/139 [==============================] - 119s 855ms/step - loss: 1.9747 - accuracy: 0.2289 - val_loss: 2.0305 - val_accuracy: 0.2067
# Epoch 43/50
# 139/139 [==============================] - 121s 869ms/step - loss: 1.9743 - accuracy: 0.2301 - val_loss: 2.0307 - val_accuracy: 0.2141
# Epoch 44/50
# 139/139 [==============================] - 120s 863ms/step - loss: 1.9787 - accuracy: 0.2297 - val_loss: 2.0180 - val_accuracy: 0.2172
# Epoch 45/50
# 139/139 [==============================] - 120s 864ms/step - loss: 1.9731 - accuracy: 0.2345 - val_loss: 2.0172 - val_accuracy: 0.2198
# Epoch 46/50
# 139/139 [==============================] - 121s 872ms/step - loss: 1.9665 - accuracy: 0.2317 - val_loss: 2.0059 - val_accuracy: 0.2298
# Epoch 47/50
# 139/139 [==============================] - 120s 864ms/step - loss: 1.9653 - accuracy: 0.2383 - val_loss: 2.0217 - val_accuracy: 0.2225
# Epoch 48/50
# 139/139 [==============================] - 120s 861ms/step - loss: 1.9672 - accuracy: 0.2338 - val_loss: 2.0285 - val_accuracy: 0.2146
# Epoch 49/50
# 139/139 [==============================] - 119s 860ms/step - loss: 1.9645 - accuracy: 0.2333 - val_loss: 2.0254 - val_accuracy: 0.2177
# Epoch 50/50
# 139/139 [==============================] - 120s 864ms/step - loss: 1.9652 - accuracy: 0.2356 - val_loss: 2.0210 - val_accuracy: 0.2162

# %%
show_plot(history2, 'Embedding(Natasha) + SimpleRNN(40) + Dropout(0.3)')

# %%
y_pred2 = model_SimpleRNN_2.predict(x_test)
show_confusion_matrix(y_test, y_pred2, CLASS_LIST_BALANCE)
# Out:
# 60/60 [==============================] - 5s 83ms/step
# Средняя точность распознавания:  20%

# %% [markdown]
# #### **Embedding(Natasha) + GRU(10) + Dropout(0.2)**

# %% [markdown]
# Слой GRU в Keras с параметрами регуляризации не считается на cuda ядрах GPU процессора. При запуске на GPU увидите предупреждение. Поэтому расчеты будут производиться долго и придется запастись терпением.

# %%
model_GRU_3 = Sequential()
model_GRU_3.add(Embedding(max_words, embedding_dim, input_length=WIN_SIZE, weights=loadEmbedding()))
model_GRU_3.add(SpatialDropout1D(0.2))
model_GRU_3.add(BatchNormalization())
# Рекуррентный слой GRU
model_GRU_3.add(GRU(10, dropout=0.2, recurrent_dropout=0.2, activation='relu'))
model_GRU_3.add(Dense(len(CLASS_LIST_BALANCE), activation='softmax'))

# %%
model_GRU_3.layers[0].trainable = False

# %%
model_GRU_3.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history3 = model_GRU_3.fit(x_train, y_train, epochs=20, batch_size=128, validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 139/139 [==============================] - 612s 4s/step - loss: 2.1553 - accuracy: 0.1387 - val_loss: 2.0626 - val_accuracy: 0.1474
# Epoch 2/20
# 139/139 [==============================] - 610s 4s/step - loss: 2.0592 - accuracy: 0.1736 - val_loss: 2.0340 - val_accuracy: 0.1899
# Epoch 3/20
# 139/139 [==============================] - 592s 4s/step - loss: 2.0174 - accuracy: 0.2041 - val_loss: 1.9855 - val_accuracy: 0.2282
# Epoch 4/20
# 139/139 [==============================] - 600s 4s/step - loss: 1.8364 - accuracy: 0.3071 - val_loss: 1.5601 - val_accuracy: 0.4418
# Epoch 5/20
# 139/139 [==============================] - 585s 4s/step - loss: 0.9744 - accuracy: 0.6582 - val_loss: 1.0372 - val_accuracy: 0.6354
# Epoch 6/20
# 139/139 [==============================] - 590s 4s/step - loss: 0.5855 - accuracy: 0.8100 - val_loss: 1.0986 - val_accuracy: 0.6348
# Epoch 7/20
# 139/139 [==============================] - 588s 4s/step - loss: 0.4394 - accuracy: 0.8587 - val_loss: 1.1979 - val_accuracy: 0.6259
# Epoch 8/20
# 139/139 [==============================] - 584s 4s/step - loss: 0.3521 - accuracy: 0.8871 - val_loss: 1.0094 - val_accuracy: 0.6779
# Epoch 9/20
# 139/139 [==============================] - 588s 4s/step - loss: 0.2907 - accuracy: 0.9064 - val_loss: 1.0067 - val_accuracy: 0.7235
# Epoch 10/20
# 139/139 [==============================] - 597s 4s/step - loss: 0.2551 - accuracy: 0.9181 - val_loss: 1.0309 - val_accuracy: 0.7104
# Epoch 11/20
# 139/139 [==============================] - 596s 4s/step - loss: 0.2205 - accuracy: 0.9303 - val_loss: 1.0828 - val_accuracy: 0.6999
# Epoch 12/20
# 139/139 [==============================] - 603s 4s/step - loss: 0.1930 - accuracy: 0.9368 - val_loss: 0.9260 - val_accuracy: 0.7366
# Epoch 13/20
# 139/139 [==============================] - 600s 4s/step - loss: 0.1705 - accuracy: 0.9462 - val_loss: 1.0035 - val_accuracy: 0.7440
# Epoch 14/20
# 139/139 [==============================] - 605s 4s/step - loss: 0.1477 - accuracy: 0.9534 - val_loss: 1.0533 - val_accuracy: 0.7025
# Epoch 15/20
# 139/139 [==============================] - 611s 4s/step - loss: 0.1464 - accuracy: 0.9509 - val_loss: 0.8198 - val_accuracy: 0.7749
# Epoch 16/20
# 139/139 [==============================] - 608s 4s/step - loss: 0.1291 - accuracy: 0.9592 - val_loss: 0.8376 - val_accuracy: 0.7608
# Epoch 17/20
# 139/139 [==============================] - 646s 5s/step - loss: 0.1167 - accuracy: 0.9619 - val_loss: 0.8493 - val_accuracy: 0.7639
# Epoch 18/20
# 139/139 [==============================] - 617s 4s/step - loss: 0.1115 - accuracy: 0.9642 - val_loss: 1.1351 - val_accuracy: 0.7403
# Epoch 19/20
# 139/139 [==============================] - 609s 4s/step - loss: 0.0971 - accuracy: 0.9679 - val_loss: 0.9224 - val_accuracy: 0.7629
# Epoch 20/20
# 139/139 [==============================] - 621s 4s/step - loss: 0.0958 - accuracy: 0.9686 - val_loss: 0.9334 - val_accuracy: 0.7592

# %%
show_plot(history3, 'Embedding(Natasha) + GRU(10) + Dropout(0.2)')

# %%
y_pred3 = model_GRU_3.predict(x_test)
show_confusion_matrix(y_test, y_pred3, CLASS_LIST_BALANCE)
# Out:
# 60/60 [==============================] - 12s 195ms/step
# Средняя точность распознавания:  75%

# %% [markdown]
# #### **Embedding(Natasha) + GRU(40) + Dropout(0.2)**

# %%
model_GRU_4 = Sequential()
model_GRU_4.add(Embedding(max_words, embedding_dim, input_length=WIN_SIZE, weights=loadEmbedding()))
model_GRU_4.add(SpatialDropout1D(0.2))
model_GRU_4.add(BatchNormalization())
# Рекуррентный слой GRU
model_GRU_4.add(GRU(40, dropout=0.2, recurrent_dropout=0.2, activation='relu'))
model_GRU_4.add(Dense(len(CLASS_LIST_BALANCE), activation='softmax'))

# %%
model_GRU_4.layers[0].trainable = False

# %%
model_GRU_4.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history4 = model_GRU_4.fit(x_train, y_train, epochs=20, batch_size=128, validation_data=(x_test, y_test))
# Out:
# Epoch 1/20
# 139/139 [==============================] - 865s 6s/step - loss: 2.1180 - accuracy: 0.1664 - val_loss: 2.0230 - val_accuracy: 0.2067
# Epoch 2/20
# 139/139 [==============================] - 878s 6s/step - loss: 1.7159 - accuracy: 0.3531 - val_loss: 1.1283 - val_accuracy: 0.6616
# Epoch 3/20
# 139/139 [==============================] - 877s 6s/step - loss: 0.4891 - accuracy: 0.8364 - val_loss: 0.6735 - val_accuracy: 0.7655
# Epoch 4/20
# 139/139 [==============================] - 868s 6s/step - loss: 0.1942 - accuracy: 0.9353 - val_loss: 0.5481 - val_accuracy: 0.8195
# Epoch 5/20
# 139/139 [==============================] - 867s 6s/step - loss: 0.1168 - accuracy: 0.9617 - val_loss: 0.5530 - val_accuracy: 0.8263
# Epoch 6/20
# 139/139 [==============================] - 870s 6s/step - loss: 0.0771 - accuracy: 0.9763 - val_loss: 0.5440 - val_accuracy: 0.8363
# Epoch 7/20
# 139/139 [==============================] - 868s 6s/step - loss: 0.0526 - accuracy: 0.9835 - val_loss: 0.5585 - val_accuracy: 0.8395
# Epoch 8/20
# 139/139 [==============================] - 870s 6s/step - loss: 0.0438 - accuracy: 0.9868 - val_loss: 0.4537 - val_accuracy: 0.8652
# Epoch 9/20
# 139/139 [==============================] - 871s 6s/step - loss: 0.0298 - accuracy: 0.9910 - val_loss: 0.5810 - val_accuracy: 0.8541
# Epoch 10/20
# 139/139 [==============================] - 883s 6s/step - loss: 0.0298 - accuracy: 0.9912 - val_loss: 0.5452 - val_accuracy: 0.8625
# Epoch 11/20
# 139/139 [==============================] - 856s 6s/step - loss: 0.0256 - accuracy: 0.9924 - val_loss: 0.3393 - val_accuracy: 0.8861
# Epoch 12/20
# 139/139 [==============================] - 865s 6s/step - loss: 0.0206 - accuracy: 0.9933 - val_loss: 0.3402 - val_accuracy: 0.9014
# Epoch 13/20
# 139/139 [==============================] - 853s 6s/step - loss: 0.0181 - accuracy: 0.9949 - val_loss: 0.3643 - val_accuracy: 0.8888
# Epoch 14/20
# 139/139 [==============================] - 882s 6s/step - loss: 0.0148 - accuracy: 0.9958 - val_loss: 0.3644 - val_accuracy: 0.8945
# Epoch 15/20
# 139/139 [==============================] - 873s 6s/step - loss: 0.0163 - accuracy: 0.9948 - val_loss: 0.5506 - val_accuracy: 0.8478
# Epoch 16/20
# 139/139 [==============================] - 856s 6s/step - loss: 0.0184 - accuracy: 0.9941 - val_loss: 0.4397 - val_accuracy: 0.8788
# Epoch 17/20
# 139/139 [==============================] - 852s 6s/step - loss: 0.0151 - accuracy: 0.9954 - val_loss: 0.3387 - val_accuracy: 0.8940
# Epoch 18/20
# 139/139 [==============================] - 839s 6s/step - loss: 0.0111 - accuracy: 0.9969 - val_loss: 0.3562 - val_accuracy: 0.9019
# Epoch 19/20
# 139/139 [==============================] - 817s 6s/step - loss: 0.0096 - accuracy: 0.9968 - val_loss: 0.2796 - val_accuracy: 0.9166
# Epoch 20/20
# 139/139 [==============================] - 825s 6s/step - loss: 0.0119 - accuracy: 0.9966 - val_loss: 0.5423 - val_accuracy: 0.8594

# %%
show_plot(history4, 'Embedding(Natasha) + GRU(40) + Dropout(0.2)')

# %%
y_pred4 = model_GRU_4.predict(x_test)
show_confusion_matrix(y_test, y_pred4, CLASS_LIST_BALANCE)
# Out:
# 60/60 [==============================] - 13s 212ms/step
# Средняя точность распознавания:  86%

# %% [markdown]
# #### **Embedding(Natasha) + LSTM(20) + Dropout(0.2)**

# %%
model_LSTM_5 = Sequential()
model_LSTM_5.add(Embedding(max_words, embedding_dim, input_length=WIN_SIZE, weights=loadEmbedding()))
model_LSTM_5.add(SpatialDropout1D(0.2))
model_LSTM_5.add(BatchNormalization())

# Рекуррентный слой LSTM
model_LSTM_5.add(LSTM(20))
model_LSTM_5.add(Dense(len(CLASS_LIST_BALANCE), activation='softmax'))

# %%
model_LSTM_5.layers[0].trainable = False

# %%
model_LSTM_5.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history5 = model_LSTM_5.fit(x_train, y_train, epochs=50, batch_size=128, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 139/139 [==============================] - 10s 54ms/step - loss: 2.0167 - accuracy: 0.1999 - val_loss: 2.0044 - val_accuracy: 0.1936
# Epoch 2/50
# 139/139 [==============================] - 7s 47ms/step - loss: 1.7877 - accuracy: 0.3344 - val_loss: 1.8982 - val_accuracy: 0.3075
# Epoch 3/50
# 139/139 [==============================] - 7s 49ms/step - loss: 1.4700 - accuracy: 0.4808 - val_loss: 1.6636 - val_accuracy: 0.4292
# Epoch 4/50
# 139/139 [==============================] - 6s 46ms/step - loss: 1.2817 - accuracy: 0.5548 - val_loss: 1.3227 - val_accuracy: 0.5205
# Epoch 5/50
# 139/139 [==============================] - 7s 50ms/step - loss: 1.1398 - accuracy: 0.6008 - val_loss: 1.3107 - val_accuracy: 0.5582
# Epoch 6/50
# 139/139 [==============================] - 6s 46ms/step - loss: 1.3709 - accuracy: 0.5152 - val_loss: 1.4240 - val_accuracy: 0.5152
# Epoch 7/50
# 139/139 [==============================] - 7s 49ms/step - loss: 1.1266 - accuracy: 0.6074 - val_loss: 1.5084 - val_accuracy: 0.5010
# Epoch 8/50
# 139/139 [==============================] - 6s 47ms/step - loss: 0.9619 - accuracy: 0.6693 - val_loss: 1.1658 - val_accuracy: 0.6380
# Epoch 9/50
# 139/139 [==============================] - 7s 49ms/step - loss: 1.0702 - accuracy: 0.6460 - val_loss: 1.3521 - val_accuracy: 0.5540
# Epoch 10/50
# 139/139 [==============================] - 7s 47ms/step - loss: 0.9617 - accuracy: 0.6763 - val_loss: 1.3935 - val_accuracy: 0.5965
# Epoch 11/50
# 139/139 [==============================] - 7s 52ms/step - loss: 0.8175 - accuracy: 0.7358 - val_loss: 1.1493 - val_accuracy: 0.6401
# Epoch 12/50
# 139/139 [==============================] - 7s 49ms/step - loss: 1.1676 - accuracy: 0.6119 - val_loss: 1.5457 - val_accuracy: 0.4365
# Epoch 13/50
# 139/139 [==============================] - 7s 47ms/step - loss: 1.0321 - accuracy: 0.6569 - val_loss: 1.2599 - val_accuracy: 0.5955
# Epoch 14/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.8012 - accuracy: 0.7452 - val_loss: 1.0646 - val_accuracy: 0.6973
# Epoch 15/50
# 139/139 [==============================] - 7s 47ms/step - loss: 0.6638 - accuracy: 0.7899 - val_loss: 1.5352 - val_accuracy: 0.5367
# Epoch 16/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.7057 - accuracy: 0.7835 - val_loss: 1.0251 - val_accuracy: 0.7025
# Epoch 17/50
# 139/139 [==============================] - 7s 47ms/step - loss: 0.5759 - accuracy: 0.8210 - val_loss: 0.9799 - val_accuracy: 0.7371
# Epoch 18/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.5117 - accuracy: 0.8423 - val_loss: 0.9892 - val_accuracy: 0.7251
# Epoch 19/50
# 139/139 [==============================] - 7s 47ms/step - loss: 0.4739 - accuracy: 0.8547 - val_loss: 0.9384 - val_accuracy: 0.7623
# Epoch 20/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.5194 - accuracy: 0.8408 - val_loss: 0.9375 - val_accuracy: 0.7471
# Epoch 21/50
# 139/139 [==============================] - 7s 48ms/step - loss: 0.4082 - accuracy: 0.8733 - val_loss: 0.8787 - val_accuracy: 0.7770
# Epoch 22/50
# 139/139 [==============================] - 7s 49ms/step - loss: 0.3795 - accuracy: 0.8822 - val_loss: 0.9744 - val_accuracy: 0.7513
# Epoch 23/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.3400 - accuracy: 0.8951 - val_loss: 0.8739 - val_accuracy: 0.7744
# Epoch 24/50
# 139/139 [==============================] - 7s 47ms/step - loss: 0.3252 - accuracy: 0.8991 - val_loss: 0.9026 - val_accuracy: 0.7650
# Epoch 25/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.3273 - accuracy: 0.9007 - val_loss: 0.8844 - val_accuracy: 0.7896
# Epoch 26/50
# 139/139 [==============================] - 7s 47ms/step - loss: 0.2917 - accuracy: 0.9126 - val_loss: 0.7985 - val_accuracy: 0.8054
# Epoch 27/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.2538 - accuracy: 0.9232 - val_loss: 0.8055 - val_accuracy: 0.7996
# Epoch 28/50
# 139/139 [==============================] - 7s 47ms/step - loss: 0.2295 - accuracy: 0.9319 - val_loss: 0.8143 - val_accuracy: 0.7980
# Epoch 29/50
# 139/139 [==============================] - 7s 51ms/step - loss: 0.2050 - accuracy: 0.9371 - val_loss: 0.7621 - val_accuracy: 0.8085
# Epoch 30/50
# 139/139 [==============================] - 7s 48ms/step - loss: 0.1932 - accuracy: 0.9439 - val_loss: 0.7666 - val_accuracy: 0.8059
# Epoch 31/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.1825 - accuracy: 0.9452 - val_loss: 0.7777 - val_accuracy: 0.8017
# Epoch 32/50
# 139/139 [==============================] - 7s 49ms/step - loss: 0.1637 - accuracy: 0.9507 - val_loss: 0.7679 - val_accuracy: 0.8216
# Epoch 33/50
# 139/139 [==============================] - 7s 48ms/step - loss: 0.1610 - accuracy: 0.9507 - val_loss: 0.7005 - val_accuracy: 0.8158
# Epoch 34/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.1514 - accuracy: 0.9552 - val_loss: 0.7025 - val_accuracy: 0.8190
# Epoch 35/50
# 139/139 [==============================] - 7s 47ms/step - loss: 0.1317 - accuracy: 0.9610 - val_loss: 0.7357 - val_accuracy: 0.8185
# Epoch 36/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.1217 - accuracy: 0.9639 - val_loss: 0.7507 - val_accuracy: 0.8321
# Epoch 37/50
# 139/139 [==============================] - 7s 48ms/step - loss: 0.1139 - accuracy: 0.9669 - val_loss: 0.7217 - val_accuracy: 0.8263
# Epoch 38/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.1022 - accuracy: 0.9705 - val_loss: 0.7205 - val_accuracy: 0.8316
# Epoch 39/50
# 139/139 [==============================] - 7s 47ms/step - loss: 0.0945 - accuracy: 0.9715 - val_loss: 0.6588 - val_accuracy: 0.8384
# Epoch 40/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.0968 - accuracy: 0.9715 - val_loss: 0.6725 - val_accuracy: 0.8463
# Epoch 41/50
# 139/139 [==============================] - 7s 52ms/step - loss: 0.0919 - accuracy: 0.9744 - val_loss: 0.6850 - val_accuracy: 0.8358
# Epoch 42/50
# 139/139 [==============================] - 7s 48ms/step - loss: 0.0779 - accuracy: 0.9773 - val_loss: 0.6922 - val_accuracy: 0.8358
# Epoch 43/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.0733 - accuracy: 0.9798 - val_loss: 0.7263 - val_accuracy: 0.8353
# Epoch 44/50
# 139/139 [==============================] - 7s 47ms/step - loss: 0.0698 - accuracy: 0.9806 - val_loss: 0.6796 - val_accuracy: 0.8410
# Epoch 45/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.0659 - accuracy: 0.9799 - val_loss: 0.7577 - val_accuracy: 0.8263
# Epoch 46/50
# 139/139 [==============================] - 7s 47ms/step - loss: 0.0701 - accuracy: 0.9795 - val_loss: 0.6953 - val_accuracy: 0.8421
# Epoch 47/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.0621 - accuracy: 0.9820 - val_loss: 0.6681 - val_accuracy: 0.8379
# Epoch 48/50
# 139/139 [==============================] - 7s 47ms/step - loss: 0.0538 - accuracy: 0.9851 - val_loss: 0.7084 - val_accuracy: 0.8358
# Epoch 49/50
# 139/139 [==============================] - 7s 50ms/step - loss: 0.0515 - accuracy: 0.9853 - val_loss: 0.6873 - val_accuracy: 0.8416
# Epoch 50/50
# 139/139 [==============================] - 7s 48ms/step - loss: 0.0496 - accuracy: 0.9863 - val_loss: 0.7268 - val_accuracy: 0.8305

# %%
show_plot(history5, 'Embedding(Natasha) + LSTM(20) + Dropout(0.2)')

# %%
y_pred5 = model_LSTM_5.predict(x_test)
show_confusion_matrix(y_test, y_pred5, CLASS_LIST_BALANCE)
# Out:
# 60/60 [==============================] - 1s 14ms/step
# Средняя точность распознавания:  83%

# %% [markdown]
# #### **Embedding(Natasha) + LSTM(100) + Dropout(0.3)**

# %%
model_LSTM_6 = Sequential()
model_LSTM_6.add(Embedding(max_words, embedding_dim, input_length=WIN_SIZE, weights=loadEmbedding()))
model_LSTM_6.add(SpatialDropout1D(0.3))
model_LSTM_6.add(BatchNormalization())

# Рекуррентный слой LSTM
model_LSTM_6.add(LSTM(100))
model_LSTM_6.add(Dense(len(CLASS_LIST_BALANCE), activation='softmax'))

# %%
model_LSTM_6.layers[0].trainable = False

# %%
model_LSTM_6.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history6 = model_LSTM_6.fit(x_train, y_train, epochs=50, batch_size=128, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 139/139 [==============================] - 15s 96ms/step - loss: 1.9309 - accuracy: 0.2464 - val_loss: 1.9731 - val_accuracy: 0.3148
# Epoch 2/50
# 139/139 [==============================] - 14s 99ms/step - loss: 1.7100 - accuracy: 0.3820 - val_loss: 1.7870 - val_accuracy: 0.3416
# Epoch 3/50
# 139/139 [==============================] - 14s 98ms/step - loss: 1.7065 - accuracy: 0.3788 - val_loss: 1.7110 - val_accuracy: 0.3841
# Epoch 4/50
# 139/139 [==============================] - 13s 96ms/step - loss: 1.5298 - accuracy: 0.4610 - val_loss: 1.5679 - val_accuracy: 0.4344
# Epoch 5/50
# 139/139 [==============================] - 13s 95ms/step - loss: 1.5810 - accuracy: 0.4436 - val_loss: 1.6815 - val_accuracy: 0.3966
# Epoch 6/50
# 139/139 [==============================] - 13s 96ms/step - loss: 1.3418 - accuracy: 0.5494 - val_loss: 1.7710 - val_accuracy: 0.4213
# Epoch 7/50
# 139/139 [==============================] - 14s 99ms/step - loss: 1.3816 - accuracy: 0.5207 - val_loss: 1.4828 - val_accuracy: 0.4963
# Epoch 8/50
# 139/139 [==============================] - 13s 96ms/step - loss: 0.9931 - accuracy: 0.6699 - val_loss: 1.2552 - val_accuracy: 0.5887
# Epoch 9/50
# 139/139 [==============================] - 14s 103ms/step - loss: 0.7365 - accuracy: 0.7608 - val_loss: 0.9467 - val_accuracy: 0.6731
# Epoch 10/50
# 139/139 [==============================] - 15s 107ms/step - loss: 0.5208 - accuracy: 0.8318 - val_loss: 0.8785 - val_accuracy: 0.7009
# Epoch 11/50
# 139/139 [==============================] - 13s 95ms/step - loss: 0.3807 - accuracy: 0.8808 - val_loss: 0.7502 - val_accuracy: 0.7497
# Epoch 12/50
# 139/139 [==============================] - 13s 96ms/step - loss: 0.3053 - accuracy: 0.9060 - val_loss: 0.7482 - val_accuracy: 0.7398
# Epoch 13/50
# 139/139 [==============================] - 14s 100ms/step - loss: 0.2301 - accuracy: 0.9279 - val_loss: 0.7874 - val_accuracy: 0.7204
# Epoch 14/50
# 139/139 [==============================] - 13s 97ms/step - loss: 0.1797 - accuracy: 0.9434 - val_loss: 0.7192 - val_accuracy: 0.7739
# Epoch 15/50
# 139/139 [==============================] - 15s 105ms/step - loss: 0.1486 - accuracy: 0.9536 - val_loss: 0.7022 - val_accuracy: 0.7833
# Epoch 16/50
# 139/139 [==============================] - 14s 98ms/step - loss: 0.1215 - accuracy: 0.9642 - val_loss: 0.7144 - val_accuracy: 0.7796
# Epoch 17/50
# 139/139 [==============================] - 14s 100ms/step - loss: 0.1018 - accuracy: 0.9688 - val_loss: 0.6903 - val_accuracy: 0.7854
# Epoch 18/50
# 139/139 [==============================] - 13s 96ms/step - loss: 0.0901 - accuracy: 0.9724 - val_loss: 0.6506 - val_accuracy: 0.7991
# Epoch 19/50
# 139/139 [==============================] - 14s 97ms/step - loss: 0.0681 - accuracy: 0.9801 - val_loss: 0.5815 - val_accuracy: 0.8248
# Epoch 20/50
# 139/139 [==============================] - 14s 97ms/step - loss: 0.0647 - accuracy: 0.9818 - val_loss: 0.5309 - val_accuracy: 0.8347
# Epoch 21/50
# 139/139 [==============================] - 13s 95ms/step - loss: 0.0517 - accuracy: 0.9851 - val_loss: 0.5759 - val_accuracy: 0.8216
# Epoch 22/50
# 139/139 [==============================] - 14s 98ms/step - loss: 0.0416 - accuracy: 0.9881 - val_loss: 0.5260 - val_accuracy: 0.8468
# Epoch 23/50
# 139/139 [==============================] - 13s 97ms/step - loss: 0.0419 - accuracy: 0.9878 - val_loss: 0.6238 - val_accuracy: 0.8043
# Epoch 24/50
# 139/139 [==============================] - 13s 95ms/step - loss: 0.0359 - accuracy: 0.9896 - val_loss: 0.5067 - val_accuracy: 0.8421
# Epoch 25/50
# 139/139 [==============================] - 13s 96ms/step - loss: 0.0339 - accuracy: 0.9902 - val_loss: 0.5577 - val_accuracy: 0.8300
# Epoch 26/50
# 139/139 [==============================] - 13s 96ms/step - loss: 0.0314 - accuracy: 0.9906 - val_loss: 0.5188 - val_accuracy: 0.8332
# Epoch 27/50
# 139/139 [==============================] - 13s 95ms/step - loss: 0.0278 - accuracy: 0.9918 - val_loss: 0.7933 - val_accuracy: 0.7828
# Epoch 28/50
# 139/139 [==============================] - 13s 96ms/step - loss: 0.0273 - accuracy: 0.9918 - val_loss: 0.5755 - val_accuracy: 0.8363
# Epoch 29/50
# 139/139 [==============================] - 13s 96ms/step - loss: 0.0347 - accuracy: 0.9913 - val_loss: 0.6168 - val_accuracy: 0.8185
# Epoch 30/50
# 139/139 [==============================] - 13s 95ms/step - loss: 0.0244 - accuracy: 0.9939 - val_loss: 0.6115 - val_accuracy: 0.8185
# Epoch 31/50
# 139/139 [==============================] - 13s 96ms/step - loss: 0.0167 - accuracy: 0.9952 - val_loss: 0.5842 - val_accuracy: 0.8311
# Epoch 32/50
# 139/139 [==============================] - 13s 96ms/step - loss: 0.0195 - accuracy: 0.9943 - val_loss: 0.4954 - val_accuracy: 0.8484
# Epoch 33/50
# 139/139 [==============================] - 14s 98ms/step - loss: 0.0151 - accuracy: 0.9955 - val_loss: 0.6207 - val_accuracy: 0.8269
# Epoch 34/50
# 139/139 [==============================] - 13s 95ms/step - loss: 0.0157 - accuracy: 0.9956 - val_loss: 0.5407 - val_accuracy: 0.8447
# Epoch 35/50
# 139/139 [==============================] - 13s 95ms/step - loss: 0.0146 - accuracy: 0.9959 - val_loss: 0.6145 - val_accuracy: 0.8242
# Epoch 36/50
# 139/139 [==============================] - 13s 95ms/step - loss: 0.0166 - accuracy: 0.9952 - val_loss: 0.6135 - val_accuracy: 0.8358
# Epoch 37/50
# 139/139 [==============================] - 13s 96ms/step - loss: 0.0190 - accuracy: 0.9943 - val_loss: 0.5757 - val_accuracy: 0.8279
# Epoch 38/50
# 139/139 [==============================] - 13s 95ms/step - loss: 0.0125 - accuracy: 0.9965 - val_loss: 0.5013 - val_accuracy: 0.8594
# Epoch 39/50
# 139/139 [==============================] - 13s 96ms/step - loss: 0.0136 - accuracy: 0.9961 - val_loss: 0.6904 - val_accuracy: 0.7991
# Epoch 40/50
# 139/139 [==============================] - 13s 95ms/step - loss: 0.0127 - accuracy: 0.9963 - val_loss: 0.5815 - val_accuracy: 0.8405
# Epoch 41/50
# 139/139 [==============================] - 13s 95ms/step - loss: 0.0141 - accuracy: 0.9952 - val_loss: 0.6077 - val_accuracy: 0.8358
# Epoch 42/50
# 139/139 [==============================] - 13s 96ms/step - loss: 0.0147 - accuracy: 0.9957 - val_loss: 0.6539 - val_accuracy: 0.8237
# Epoch 43/50
# 139/139 [==============================] - 13s 95ms/step - loss: 0.0118 - accuracy: 0.9968 - val_loss: 0.4771 - val_accuracy: 0.8652
# Epoch 44/50
# 139/139 [==============================] - 13s 96ms/step - loss: 0.0115 - accuracy: 0.9970 - val_loss: 0.5860 - val_accuracy: 0.8405
# Epoch 45/50
# 139/139 [==============================] - 13s 95ms/step - loss: 0.0096 - accuracy: 0.9971 - val_loss: 0.5472 - val_accuracy: 0.8578
# Epoch 46/50
# 139/139 [==============================] - 13s 95ms/step - loss: 0.0083 - accuracy: 0.9977 - val_loss: 0.6275 - val_accuracy: 0.8405
# Epoch 47/50
# 139/139 [==============================] - 13s 95ms/step - loss: 0.0091 - accuracy: 0.9977 - val_loss: 0.6603 - val_accuracy: 0.8358
# Epoch 48/50
# 139/139 [==============================] - 13s 96ms/step - loss: 0.0123 - accuracy: 0.9962 - val_loss: 0.5314 - val_accuracy: 0.8515
# Epoch 49/50
# 139/139 [==============================] - 13s 96ms/step - loss: 0.0147 - accuracy: 0.9956 - val_loss: 0.4835 - val_accuracy: 0.8416
# Epoch 50/50
# 139/139 [==============================] - 13s 95ms/step - loss: 0.0111 - accuracy: 0.9971 - val_loss: 0.5552 - val_accuracy: 0.8195

# %%
show_plot(history6, 'Embedding(Natasha) + LSTM(100) + Dropout(0.3)')

# %%
y_pred6 = model_LSTM_6.predict(x_test)
show_confusion_matrix(y_test, y_pred6, CLASS_LIST_BALANCE)
# Out:
# 60/60 [==============================] - 1s 16ms/step
# Средняя точность распознавания:  83%

# %% [markdown]
# #### **Embedding(Natasha) + BLSTM(8)x2 + GRU(16)x2 + Dropout(0.3) + Dense(100)**

# %% [markdown]
# `Bidirectional(LSTM(8, return_sequences=True))` – этот слой
# активизирует двунаправленную сеть **LSTM**;
#
# `GRU(16, return_sequences=True, reset_after=True)` – параметр `reset_after=True` означает сброс данных.

# %%
model_MIX = Sequential()
model_MIX.add(Embedding(max_words, embedding_dim, input_length=WIN_SIZE, weights=loadEmbedding()))
model_MIX.add(SpatialDropout1D(0.3))
model_MIX.add(BatchNormalization())

# Два двунаправленных рекуррентных слоя LSTM
model_MIX.add(Bidirectional(LSTM(8, return_sequences=True)))
model_MIX.add(Bidirectional(LSTM(8, return_sequences=True)))
model_MIX.add(Dropout(0.3))
model_MIX.add(BatchNormalization())

# Два рекуррентных слоя GRU
model_MIX.add(GRU(16, return_sequences=True, reset_after=True))
model_MIX.add(GRU(16, reset_after=True))
model_MIX.add(Dropout(0.3))
model_MIX.add(BatchNormalization())

# Дополнительный полносвязный слой
model_MIX.add(Dense(100, activation='relu'))
model_MIX.add(Dropout(0.3))
model_MIX.add(BatchNormalization())
model_MIX.add(Dense(len(CLASS_LIST_BALANCE), activation='softmax'))

# %%
model_MIX.layers[0].trainable = False

# %%
model_MIX.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history_mix = model_MIX.fit(x_train, y_train, epochs=50, batch_size=128, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 139/139 [==============================] - 40s 205ms/step - loss: 2.3619 - accuracy: 0.1393 - val_loss: 2.0766 - val_accuracy: 0.1359
# Epoch 2/50
# 139/139 [==============================] - 25s 181ms/step - loss: 2.1287 - accuracy: 0.1794 - val_loss: 2.0446 - val_accuracy: 0.2004
# Epoch 3/50
# 139/139 [==============================] - 25s 184ms/step - loss: 2.0026 - accuracy: 0.2267 - val_loss: 1.9965 - val_accuracy: 0.2566
# Epoch 4/50
# 139/139 [==============================] - 26s 185ms/step - loss: 1.8282 - accuracy: 0.3216 - val_loss: 1.9133 - val_accuracy: 0.3478
# Epoch 5/50
# 139/139 [==============================] - 26s 185ms/step - loss: 1.7276 - accuracy: 0.3663 - val_loss: 1.8524 - val_accuracy: 0.3715
# Epoch 6/50
# 139/139 [==============================] - 25s 183ms/step - loss: 1.5570 - accuracy: 0.4374 - val_loss: 1.7434 - val_accuracy: 0.4423
# Epoch 7/50
# 139/139 [==============================] - 26s 188ms/step - loss: 1.4392 - accuracy: 0.4839 - val_loss: 1.6279 - val_accuracy: 0.4402
# Epoch 8/50
# 139/139 [==============================] - 26s 186ms/step - loss: 1.3196 - accuracy: 0.5136 - val_loss: 1.2770 - val_accuracy: 0.6322
# Epoch 9/50
# 139/139 [==============================] - 25s 178ms/step - loss: 1.0932 - accuracy: 0.5977 - val_loss: 1.4632 - val_accuracy: 0.4654
# Epoch 10/50
# 139/139 [==============================] - 25s 178ms/step - loss: 0.9411 - accuracy: 0.6481 - val_loss: 1.3764 - val_accuracy: 0.5362
# Epoch 11/50
# 139/139 [==============================] - 25s 178ms/step - loss: 0.8698 - accuracy: 0.6770 - val_loss: 1.7844 - val_accuracy: 0.4622
# Epoch 12/50
# 139/139 [==============================] - 25s 179ms/step - loss: 0.7794 - accuracy: 0.7139 - val_loss: 1.0860 - val_accuracy: 0.6863
# Epoch 13/50
# 139/139 [==============================] - 25s 178ms/step - loss: 0.7048 - accuracy: 0.7396 - val_loss: 0.9371 - val_accuracy: 0.7204
# Epoch 14/50
# 139/139 [==============================] - 25s 181ms/step - loss: 0.6240 - accuracy: 0.7721 - val_loss: 0.8940 - val_accuracy: 0.7261
# Epoch 15/50
# 139/139 [==============================] - 25s 178ms/step - loss: 0.5810 - accuracy: 0.7901 - val_loss: 0.8234 - val_accuracy: 0.7455
# Epoch 16/50
# 139/139 [==============================] - 26s 185ms/step - loss: 0.5360 - accuracy: 0.8041 - val_loss: 0.7984 - val_accuracy: 0.7618
# Epoch 17/50
# 139/139 [==============================] - 25s 181ms/step - loss: 0.4859 - accuracy: 0.8213 - val_loss: 0.7269 - val_accuracy: 0.8043
# Epoch 18/50
# 139/139 [==============================] - 25s 182ms/step - loss: 0.4457 - accuracy: 0.8366 - val_loss: 0.7118 - val_accuracy: 0.7880
# Epoch 19/50
# 139/139 [==============================] - 25s 181ms/step - loss: 0.4100 - accuracy: 0.8518 - val_loss: 0.7277 - val_accuracy: 0.7870
# Epoch 20/50
# 139/139 [==============================] - 25s 178ms/step - loss: 0.3733 - accuracy: 0.8673 - val_loss: 0.7179 - val_accuracy: 0.7896
# Epoch 21/50
# 139/139 [==============================] - 25s 181ms/step - loss: 0.3362 - accuracy: 0.8813 - val_loss: 0.6285 - val_accuracy: 0.8300
# Epoch 22/50
# 139/139 [==============================] - 25s 179ms/step - loss: 0.3146 - accuracy: 0.8890 - val_loss: 0.5936 - val_accuracy: 0.8284
# Epoch 23/50
# 139/139 [==============================] - 25s 181ms/step - loss: 0.2784 - accuracy: 0.9018 - val_loss: 0.5342 - val_accuracy: 0.8573
# Epoch 24/50
# 139/139 [==============================] - 26s 186ms/step - loss: 0.2491 - accuracy: 0.9133 - val_loss: 0.7410 - val_accuracy: 0.8085
# Epoch 25/50
# 139/139 [==============================] - 25s 178ms/step - loss: 0.2231 - accuracy: 0.9240 - val_loss: 0.5705 - val_accuracy: 0.8646
# Epoch 26/50
# 139/139 [==============================] - 25s 180ms/step - loss: 0.1948 - accuracy: 0.9331 - val_loss: 0.5632 - val_accuracy: 0.8589
# Epoch 27/50
# 139/139 [==============================] - 25s 178ms/step - loss: 0.1889 - accuracy: 0.9372 - val_loss: 0.5240 - val_accuracy: 0.8736
# Epoch 28/50
# 139/139 [==============================] - 25s 178ms/step - loss: 0.1724 - accuracy: 0.9418 - val_loss: 0.5560 - val_accuracy: 0.8694
# Epoch 29/50
# 139/139 [==============================] - 25s 178ms/step - loss: 0.1439 - accuracy: 0.9533 - val_loss: 0.5852 - val_accuracy: 0.8877
# Epoch 30/50
# 139/139 [==============================] - 25s 177ms/step - loss: 0.1362 - accuracy: 0.9568 - val_loss: 0.6654 - val_accuracy: 0.8589
# Epoch 31/50
# 139/139 [==============================] - 25s 178ms/step - loss: 0.1300 - accuracy: 0.9565 - val_loss: 0.8026 - val_accuracy: 0.8526
# Epoch 32/50
# 139/139 [==============================] - 26s 185ms/step - loss: 0.1157 - accuracy: 0.9628 - val_loss: 0.6348 - val_accuracy: 0.8825
# Epoch 33/50
# 139/139 [==============================] - 25s 178ms/step - loss: 0.1131 - accuracy: 0.9642 - val_loss: 0.6349 - val_accuracy: 0.8615
# Epoch 34/50
# 139/139 [==============================] - 25s 180ms/step - loss: 0.1019 - accuracy: 0.9676 - val_loss: 0.5685 - val_accuracy: 0.8793
# Epoch 35/50
# 139/139 [==============================] - 25s 177ms/step - loss: 0.0981 - accuracy: 0.9691 - val_loss: 0.6043 - val_accuracy: 0.8841
# Epoch 36/50
# 139/139 [==============================] - 25s 179ms/step - loss: 0.0891 - accuracy: 0.9724 - val_loss: 0.5760 - val_accuracy: 0.8945
# Epoch 37/50
# 139/139 [==============================] - 25s 181ms/step - loss: 0.0916 - accuracy: 0.9708 - val_loss: 0.5860 - val_accuracy: 0.8746
# Epoch 38/50
# 139/139 [==============================] - 25s 178ms/step - loss: 0.0805 - accuracy: 0.9748 - val_loss: 0.6638 - val_accuracy: 0.8788
# Epoch 39/50
# 139/139 [==============================] - 25s 181ms/step - loss: 0.0711 - accuracy: 0.9773 - val_loss: 0.6112 - val_accuracy: 0.8924
# Epoch 40/50
# 139/139 [==============================] - 26s 184ms/step - loss: 0.0681 - accuracy: 0.9788 - val_loss: 0.6140 - val_accuracy: 0.8898
# Epoch 41/50
# 139/139 [==============================] - 25s 179ms/step - loss: 0.0706 - accuracy: 0.9788 - val_loss: 0.6026 - val_accuracy: 0.8861
# Epoch 42/50
# 139/139 [==============================] - 25s 179ms/step - loss: 0.0724 - accuracy: 0.9790 - val_loss: 0.5598 - val_accuracy: 0.8945
# Epoch 43/50
# 139/139 [==============================] - 25s 179ms/step - loss: 0.0627 - accuracy: 0.9825 - val_loss: 0.7082 - val_accuracy: 0.8694
# Epoch 44/50
# 139/139 [==============================] - 25s 179ms/step - loss: 0.0585 - accuracy: 0.9825 - val_loss: 0.6176 - val_accuracy: 0.8987
# Epoch 45/50
# 139/139 [==============================] - 25s 180ms/step - loss: 0.0569 - accuracy: 0.9824 - val_loss: 0.6302 - val_accuracy: 0.8919
# Epoch 46/50
# 139/139 [==============================] - 25s 179ms/step - loss: 0.0444 - accuracy: 0.9874 - val_loss: 0.6767 - val_accuracy: 0.8762
# Epoch 47/50
# 139/139 [==============================] - 25s 179ms/step - loss: 0.0562 - accuracy: 0.9835 - val_loss: 0.8423 - val_accuracy: 0.8625
# Epoch 48/50
# 139/139 [==============================] - 26s 184ms/step - loss: 0.0524 - accuracy: 0.9826 - val_loss: 0.6873 - val_accuracy: 0.8830
# Epoch 49/50
# 139/139 [==============================] - 25s 178ms/step - loss: 0.0504 - accuracy: 0.9848 - val_loss: 0.7939 - val_accuracy: 0.8688
# Epoch 50/50
# 139/139 [==============================] - 25s 180ms/step - loss: 0.0471 - accuracy: 0.9856 - val_loss: 0.7164 - val_accuracy: 0.8861

# %%
show_plot(history_mix, 'Embedding(Natasha) + BLSTM(8)x2 + GRU(16)x2 + Dropout(0.3) + Dense(100)')

# %%
y_pred_mix = model_MIX.predict(x_test)
show_confusion_matrix(y_test, y_pred_mix, CLASS_LIST_BALANCE)
# Out:
# 60/60 [==============================] - 7s 79ms/step
# Средняя точность распознавания:  89%

# %% [markdown]
# #### **Embedding(Natasha) + Conv1D(20)x2 + Dropout(0.2)**

# %%
model_Conv1D = Sequential()
model_Conv1D.add(Embedding(max_words, embedding_dim, input_length=WIN_SIZE, weights=loadEmbedding()))
model_Conv1D.add(SpatialDropout1D(0.2))
model_Conv1D.add(BatchNormalization())
# Два слоя одномерной свертки Conv1D
model_Conv1D.add(Conv1D(20, 5, activation='relu', padding='same'))
model_Conv1D.add(Conv1D(20, 5, activation='relu'))
# Слой подвыборки/пулинга с функцией максимума
model_Conv1D.add(MaxPooling1D(2))
model_Conv1D.add(Dropout(0.2))
# Слой пакетной нормализации
model_Conv1D.add(BatchNormalization())
# Слой выравнивания в вектор
model_Conv1D.add(Flatten())
model_Conv1D.add(Dense(len(CLASS_LIST_BALANCE), activation='softmax'))

# %%
model_Conv1D.layers[0].trainable = False

# %%
model_Conv1D.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history_1D = model_Conv1D.fit(x_train, y_train, epochs=50, batch_size=128, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 139/139 [==============================] - 14s 40ms/step - loss: 1.5092 - accuracy: 0.5096 - val_loss: 6.5058 - val_accuracy: 0.1327
# Epoch 2/50
# 139/139 [==============================] - 5s 34ms/step - loss: 0.4495 - accuracy: 0.8438 - val_loss: 7.1744 - val_accuracy: 0.1663
# Epoch 3/50
# 139/139 [==============================] - 5s 34ms/step - loss: 0.2064 - accuracy: 0.9281 - val_loss: 4.0421 - val_accuracy: 0.3599
# Epoch 4/50
# 139/139 [==============================] - 5s 35ms/step - loss: 0.1149 - accuracy: 0.9614 - val_loss: 1.8543 - val_accuracy: 0.6254
# Epoch 5/50
# 139/139 [==============================] - 5s 36ms/step - loss: 0.0723 - accuracy: 0.9767 - val_loss: 1.2098 - val_accuracy: 0.7466
# Epoch 6/50
# 139/139 [==============================] - 5s 34ms/step - loss: 0.0529 - accuracy: 0.9830 - val_loss: 0.9605 - val_accuracy: 0.7886
# Epoch 7/50
# 139/139 [==============================] - 5s 36ms/step - loss: 0.0407 - accuracy: 0.9874 - val_loss: 0.8956 - val_accuracy: 0.8101
# Epoch 8/50
# 139/139 [==============================] - 5s 36ms/step - loss: 0.0357 - accuracy: 0.9888 - val_loss: 1.2565 - val_accuracy: 0.7702
# Epoch 9/50
# 139/139 [==============================] - 5s 35ms/step - loss: 0.0291 - accuracy: 0.9909 - val_loss: 1.0358 - val_accuracy: 0.8111
# Epoch 10/50
# 139/139 [==============================] - 5s 36ms/step - loss: 0.0261 - accuracy: 0.9917 - val_loss: 0.9816 - val_accuracy: 0.8195
# Epoch 11/50
# 139/139 [==============================] - 5s 36ms/step - loss: 0.0243 - accuracy: 0.9932 - val_loss: 1.0146 - val_accuracy: 0.8153
# Epoch 12/50
# 139/139 [==============================] - 5s 38ms/step - loss: 0.0196 - accuracy: 0.9936 - val_loss: 0.8249 - val_accuracy: 0.8431
# Epoch 13/50
# 139/139 [==============================] - 5s 36ms/step - loss: 0.0190 - accuracy: 0.9944 - val_loss: 1.0352 - val_accuracy: 0.8137
# Epoch 14/50
# 139/139 [==============================] - 5s 36ms/step - loss: 0.0177 - accuracy: 0.9948 - val_loss: 1.0170 - val_accuracy: 0.8012
# Epoch 15/50
# 139/139 [==============================] - 5s 37ms/step - loss: 0.0144 - accuracy: 0.9955 - val_loss: 0.8554 - val_accuracy: 0.8416
# Epoch 16/50
# 139/139 [==============================] - 5s 37ms/step - loss: 0.0143 - accuracy: 0.9952 - val_loss: 1.1343 - val_accuracy: 0.8269
# Epoch 17/50
# 139/139 [==============================] - 5s 37ms/step - loss: 0.0158 - accuracy: 0.9953 - val_loss: 0.8583 - val_accuracy: 0.8578
# Epoch 18/50
# 139/139 [==============================] - 5s 36ms/step - loss: 0.0156 - accuracy: 0.9945 - val_loss: 0.8791 - val_accuracy: 0.8594
# Epoch 19/50
# 139/139 [==============================] - 5s 37ms/step - loss: 0.0299 - accuracy: 0.9919 - val_loss: 1.6160 - val_accuracy: 0.7707
# Epoch 20/50
# 139/139 [==============================] - 5s 35ms/step - loss: 0.0218 - accuracy: 0.9928 - val_loss: 1.2056 - val_accuracy: 0.8106
# Epoch 21/50
# 139/139 [==============================] - 5s 35ms/step - loss: 0.0245 - accuracy: 0.9914 - val_loss: 1.1373 - val_accuracy: 0.8242
# Epoch 22/50
# 139/139 [==============================] - 5s 36ms/step - loss: 0.0268 - accuracy: 0.9912 - val_loss: 1.3209 - val_accuracy: 0.8043
# Epoch 23/50
# 139/139 [==============================] - 5s 35ms/step - loss: 0.0193 - accuracy: 0.9933 - val_loss: 1.0023 - val_accuracy: 0.8274
# Epoch 24/50
# 139/139 [==============================] - 5s 37ms/step - loss: 0.0176 - accuracy: 0.9938 - val_loss: 1.0637 - val_accuracy: 0.8043
# Epoch 25/50
# 139/139 [==============================] - 5s 35ms/step - loss: 0.0162 - accuracy: 0.9942 - val_loss: 1.2447 - val_accuracy: 0.8494
# Epoch 26/50
# 139/139 [==============================] - 5s 35ms/step - loss: 0.0207 - accuracy: 0.9930 - val_loss: 1.1166 - val_accuracy: 0.8657
# Epoch 27/50
# 139/139 [==============================] - 5s 36ms/step - loss: 0.0209 - accuracy: 0.9931 - val_loss: 1.6091 - val_accuracy: 0.8374
# Epoch 28/50
# 139/139 [==============================] - 5s 35ms/step - loss: 0.0175 - accuracy: 0.9938 - val_loss: 1.8139 - val_accuracy: 0.7833
# Epoch 29/50
# 139/139 [==============================] - 5s 36ms/step - loss: 0.0194 - accuracy: 0.9935 - val_loss: 1.3507 - val_accuracy: 0.8321
# Epoch 30/50
# 139/139 [==============================] - 5s 36ms/step - loss: 0.0180 - accuracy: 0.9944 - val_loss: 1.6205 - val_accuracy: 0.8158
# Epoch 31/50
# 139/139 [==============================] - 5s 37ms/step - loss: 0.0238 - accuracy: 0.9932 - val_loss: 1.8533 - val_accuracy: 0.7823
# Epoch 32/50
# 139/139 [==============================] - 5s 37ms/step - loss: 0.0186 - accuracy: 0.9938 - val_loss: 1.3167 - val_accuracy: 0.8547
# Epoch 33/50
# 139/139 [==============================] - 5s 36ms/step - loss: 0.0168 - accuracy: 0.9953 - val_loss: 1.6286 - val_accuracy: 0.8484
# Epoch 34/50
# 139/139 [==============================] - 5s 36ms/step - loss: 0.0168 - accuracy: 0.9946 - val_loss: 1.5434 - val_accuracy: 0.8321
# Epoch 35/50
# 139/139 [==============================] - 5s 35ms/step - loss: 0.0151 - accuracy: 0.9953 - val_loss: 1.3460 - val_accuracy: 0.8389
# Epoch 36/50
# 139/139 [==============================] - 5s 36ms/step - loss: 0.0156 - accuracy: 0.9949 - val_loss: 1.9821 - val_accuracy: 0.7754
# Epoch 37/50
# 139/139 [==============================] - 5s 35ms/step - loss: 0.0215 - accuracy: 0.9937 - val_loss: 1.6146 - val_accuracy: 0.8069
# Epoch 38/50
# 139/139 [==============================] - 5s 36ms/step - loss: 0.0166 - accuracy: 0.9949 - val_loss: 1.6511 - val_accuracy: 0.8389
# Epoch 39/50
# 139/139 [==============================] - 5s 37ms/step - loss: 0.0177 - accuracy: 0.9948 - val_loss: 1.4227 - val_accuracy: 0.8258
# Epoch 40/50
# 139/139 [==============================] - 5s 35ms/step - loss: 0.0162 - accuracy: 0.9955 - val_loss: 2.0715 - val_accuracy: 0.8080
# Epoch 41/50
# 139/139 [==============================] - 5s 36ms/step - loss: 0.0134 - accuracy: 0.9958 - val_loss: 1.6281 - val_accuracy: 0.8353
# Epoch 42/50
# 139/139 [==============================] - 5s 35ms/step - loss: 0.0184 - accuracy: 0.9939 - val_loss: 1.4380 - val_accuracy: 0.8316
# Epoch 43/50
# 139/139 [==============================] - 5s 36ms/step - loss: 0.0129 - accuracy: 0.9961 - val_loss: 1.5443 - val_accuracy: 0.8148
# Epoch 44/50
# 139/139 [==============================] - 5s 35ms/step - loss: 0.0142 - accuracy: 0.9955 - val_loss: 1.5696 - val_accuracy: 0.8269
# Epoch 45/50
# 139/139 [==============================] - 5s 35ms/step - loss: 0.0122 - accuracy: 0.9959 - val_loss: 2.0149 - val_accuracy: 0.8059
# Epoch 46/50
# 139/139 [==============================] - 5s 37ms/step - loss: 0.0125 - accuracy: 0.9955 - val_loss: 1.9151 - val_accuracy: 0.8347
# Epoch 47/50
# 139/139 [==============================] - 5s 35ms/step - loss: 0.0162 - accuracy: 0.9951 - val_loss: 1.6969 - val_accuracy: 0.8499
# Epoch 48/50
# 139/139 [==============================] - 5s 37ms/step - loss: 0.0141 - accuracy: 0.9957 - val_loss: 1.7202 - val_accuracy: 0.8137
# Epoch 49/50
# 139/139 [==============================] - 5s 36ms/step - loss: 0.0154 - accuracy: 0.9949 - val_loss: 1.6350 - val_accuracy: 0.8442
# Epoch 50/50
# 139/139 [==============================] - 5s 36ms/step - loss: 0.0128 - accuracy: 0.9966 - val_loss: 2.6138 - val_accuracy: 0.7665

# %%
show_plot(history_1D, 'Embedding(Natasha) + Conv1D(20)x2 + Dropout(0.2)')

# %%
y_pred_1d = model_Conv1D.predict(x_test)
show_confusion_matrix(y_test, y_pred_1d, CLASS_LIST_BALANCE)
# Out:
# 60/60 [==============================] - 1s 5ms/step
# Средняя точность распознавания:  76%

# %% [markdown]
# #### **Embedding(Natasha) + Conv1D(20)x3 + LSTM(4)x2 + Dropout(0.2) + Dense(100)**

# %%
model_Conv_LSTM = Sequential()
model_Conv_LSTM.add(Embedding(max_words, embedding_dim, input_length=WIN_SIZE, weights=loadEmbedding()))
model_Conv_LSTM.add(SpatialDropout1D(0.2))
# Рекуррентный слой LSTM
model_Conv_LSTM.add(LSTM(4, return_sequences=1))
# Полносвязный слой
model_Conv_LSTM.add(Dense(100, activation='relu'))
# Сверточный слой
model_Conv_LSTM.add(Conv1D(20, 5, activation='relu'))
# Рекуррентный слой LSTM
model_Conv_LSTM.add(LSTM(4, return_sequences=1))
# Слой регуляризации Dropout
model_Conv_LSTM.add(Dropout(0.2))
# Слой пакетной нормализации
model_Conv_LSTM.add(BatchNormalization())
# Два сверточных слоя
model_Conv_LSTM.add(Conv1D(20, 5, activation='relu'))
model_Conv_LSTM.add(Conv1D(20, 5, activation='relu'))
# Слой подвыборки/пулинга с функцией максимума
model_Conv_LSTM.add(MaxPooling1D(2))
model_Conv_LSTM.add(Dropout(0.2))
model_Conv_LSTM.add(BatchNormalization())
# Слой выравнивания в вектор
model_Conv_LSTM.add(Flatten())
model_Conv_LSTM.add(Dense(len(CLASS_LIST_BALANCE), activation='softmax'))

# %%
model_Conv_LSTM.layers[0].trainable = False

# %%
model_Conv_LSTM.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history_1D_LSTM = model_Conv_LSTM.fit(x_train, y_train, epochs=50, batch_size=128, validation_data=(x_test, y_test))
# Out:
# Epoch 1/50
# 139/139 [==============================] - 23s 98ms/step - loss: 2.2519 - accuracy: 0.2615 - val_loss: 2.9199 - val_accuracy: 0.1495
# Epoch 2/50
# 139/139 [==============================] - 15s 109ms/step - loss: 1.3634 - accuracy: 0.5077 - val_loss: 8.4237 - val_accuracy: 0.0834
# Epoch 3/50
# 139/139 [==============================] - 9s 67ms/step - loss: 0.8016 - accuracy: 0.7031 - val_loss: 4.0124 - val_accuracy: 0.2030
# Epoch 4/50
# 139/139 [==============================] - 9s 66ms/step - loss: 0.5716 - accuracy: 0.7907 - val_loss: 3.7414 - val_accuracy: 0.1915
# Epoch 5/50
# 139/139 [==============================] - 9s 66ms/step - loss: 0.4464 - accuracy: 0.8364 - val_loss: 1.5735 - val_accuracy: 0.5960
# Epoch 6/50
# 139/139 [==============================] - 9s 64ms/step - loss: 0.3517 - accuracy: 0.8741 - val_loss: 1.4073 - val_accuracy: 0.7057
# Epoch 7/50
# 139/139 [==============================] - 9s 67ms/step - loss: 0.2865 - accuracy: 0.8969 - val_loss: 1.2124 - val_accuracy: 0.7356
# Epoch 8/50
# 139/139 [==============================] - 9s 66ms/step - loss: 0.2316 - accuracy: 0.9172 - val_loss: 1.3763 - val_accuracy: 0.6773
# Epoch 9/50
# 139/139 [==============================] - 9s 66ms/step - loss: 0.2188 - accuracy: 0.9234 - val_loss: 1.1921 - val_accuracy: 0.7655
# Epoch 10/50
# 139/139 [==============================] - 9s 63ms/step - loss: 0.1947 - accuracy: 0.9324 - val_loss: 2.2134 - val_accuracy: 0.6637
# Epoch 11/50
# 139/139 [==============================] - 9s 68ms/step - loss: 0.1722 - accuracy: 0.9409 - val_loss: 1.8340 - val_accuracy: 0.6222
# Epoch 12/50
# 139/139 [==============================] - 9s 67ms/step - loss: 0.1461 - accuracy: 0.9501 - val_loss: 1.3546 - val_accuracy: 0.7424
# Epoch 13/50
# 139/139 [==============================] - 9s 66ms/step - loss: 0.1224 - accuracy: 0.9571 - val_loss: 1.8339 - val_accuracy: 0.6558
# Epoch 14/50
# 139/139 [==============================] - 9s 65ms/step - loss: 0.1194 - accuracy: 0.9563 - val_loss: 2.1406 - val_accuracy: 0.6537
# Epoch 15/50
# 139/139 [==============================] - 10s 69ms/step - loss: 0.1184 - accuracy: 0.9581 - val_loss: 2.0081 - val_accuracy: 0.6348
# Epoch 16/50
# 139/139 [==============================] - 9s 68ms/step - loss: 0.1095 - accuracy: 0.9609 - val_loss: 1.9068 - val_accuracy: 0.7183
# Epoch 17/50
# 139/139 [==============================] - 9s 66ms/step - loss: 0.1010 - accuracy: 0.9654 - val_loss: 1.2989 - val_accuracy: 0.7723
# Epoch 18/50
# 139/139 [==============================] - 9s 68ms/step - loss: 0.0869 - accuracy: 0.9696 - val_loss: 1.5983 - val_accuracy: 0.7712
# Epoch 19/50
# 139/139 [==============================] - 9s 64ms/step - loss: 0.0927 - accuracy: 0.9682 - val_loss: 1.7842 - val_accuracy: 0.7225
# Epoch 20/50
# 139/139 [==============================] - 9s 68ms/step - loss: 0.0881 - accuracy: 0.9701 - val_loss: 1.5541 - val_accuracy: 0.7718
# Epoch 21/50
# 139/139 [==============================] - 10s 69ms/step - loss: 0.0729 - accuracy: 0.9752 - val_loss: 1.4731 - val_accuracy: 0.7686
# Epoch 22/50
# 139/139 [==============================] - 10s 69ms/step - loss: 0.0695 - accuracy: 0.9763 - val_loss: 1.7059 - val_accuracy: 0.7618
# Epoch 23/50
# 139/139 [==============================] - 9s 66ms/step - loss: 0.0650 - accuracy: 0.9779 - val_loss: 1.5524 - val_accuracy: 0.7786
# Epoch 24/50
# 139/139 [==============================] - 9s 66ms/step - loss: 0.0675 - accuracy: 0.9766 - val_loss: 1.9015 - val_accuracy: 0.7319
# Epoch 25/50
# 139/139 [==============================] - 10s 69ms/step - loss: 0.0633 - accuracy: 0.9781 - val_loss: 1.9029 - val_accuracy: 0.7718
# Epoch 26/50
# 139/139 [==============================] - 9s 66ms/step - loss: 0.0607 - accuracy: 0.9795 - val_loss: 2.4454 - val_accuracy: 0.6836
# Epoch 27/50
# 139/139 [==============================] - 9s 68ms/step - loss: 0.0601 - accuracy: 0.9806 - val_loss: 1.9164 - val_accuracy: 0.7508
# Epoch 28/50
# 139/139 [==============================] - 9s 68ms/step - loss: 0.0534 - accuracy: 0.9817 - val_loss: 1.9733 - val_accuracy: 0.7518
# Epoch 29/50
# 139/139 [==============================] - 9s 68ms/step - loss: 0.0506 - accuracy: 0.9826 - val_loss: 2.3453 - val_accuracy: 0.7524
# Epoch 30/50
# 139/139 [==============================] - 10s 69ms/step - loss: 0.0647 - accuracy: 0.9780 - val_loss: 2.2776 - val_accuracy: 0.7576
# Epoch 31/50
# 139/139 [==============================] - 9s 67ms/step - loss: 0.0635 - accuracy: 0.9802 - val_loss: 1.7827 - val_accuracy: 0.7419
# Epoch 32/50
# 139/139 [==============================] - 9s 66ms/step - loss: 0.0530 - accuracy: 0.9811 - val_loss: 1.6777 - val_accuracy: 0.7802
# Epoch 33/50
# 139/139 [==============================] - 9s 66ms/step - loss: 0.0516 - accuracy: 0.9837 - val_loss: 2.1676 - val_accuracy: 0.7671
# Epoch 34/50
# 139/139 [==============================] - 10s 71ms/step - loss: 0.0502 - accuracy: 0.9830 - val_loss: 1.7273 - val_accuracy: 0.7844
# Epoch 35/50
# 139/139 [==============================] - 9s 67ms/step - loss: 0.0571 - accuracy: 0.9812 - val_loss: 2.4355 - val_accuracy: 0.7319
# Epoch 36/50
# 139/139 [==============================] - 9s 66ms/step - loss: 0.0491 - accuracy: 0.9831 - val_loss: 1.7217 - val_accuracy: 0.7796
# Epoch 37/50
# 139/139 [==============================] - 9s 63ms/step - loss: 0.0453 - accuracy: 0.9853 - val_loss: 1.6992 - val_accuracy: 0.7823
# Epoch 38/50
# 139/139 [==============================] - 9s 67ms/step - loss: 0.0488 - accuracy: 0.9840 - val_loss: 2.4318 - val_accuracy: 0.7130
# Epoch 39/50
# 139/139 [==============================] - 10s 68ms/step - loss: 0.0374 - accuracy: 0.9865 - val_loss: 2.4870 - val_accuracy: 0.7597
# Epoch 40/50
# 139/139 [==============================] - 9s 66ms/step - loss: 0.0450 - accuracy: 0.9851 - val_loss: 1.9281 - val_accuracy: 0.7870
# Epoch 41/50
# 139/139 [==============================] - 9s 64ms/step - loss: 0.0446 - accuracy: 0.9860 - val_loss: 1.7158 - val_accuracy: 0.8085
# Epoch 42/50
# 139/139 [==============================] - 9s 68ms/step - loss: 0.0383 - accuracy: 0.9868 - val_loss: 2.4298 - val_accuracy: 0.7482
# Epoch 43/50
# 139/139 [==============================] - 9s 68ms/step - loss: 0.0381 - accuracy: 0.9874 - val_loss: 2.9100 - val_accuracy: 0.7004
# Epoch 44/50
# 139/139 [==============================] - 9s 67ms/step - loss: 0.0440 - accuracy: 0.9850 - val_loss: 2.2940 - val_accuracy: 0.7413
# Epoch 45/50
# 139/139 [==============================] - 9s 66ms/step - loss: 0.0372 - accuracy: 0.9882 - val_loss: 2.4281 - val_accuracy: 0.7277
# Epoch 46/50
# 139/139 [==============================] - 9s 64ms/step - loss: 0.0341 - accuracy: 0.9881 - val_loss: 1.7891 - val_accuracy: 0.7844
# Epoch 47/50
# 139/139 [==============================] - 9s 66ms/step - loss: 0.0408 - accuracy: 0.9877 - val_loss: 3.0381 - val_accuracy: 0.6805
# Epoch 48/50
# 139/139 [==============================] - 9s 67ms/step - loss: 0.0395 - accuracy: 0.9863 - val_loss: 2.0061 - val_accuracy: 0.7629
# Epoch 49/50
# 139/139 [==============================] - 9s 67ms/step - loss: 0.0382 - accuracy: 0.9878 - val_loss: 1.9056 - val_accuracy: 0.7733
# Epoch 50/50
# 139/139 [==============================] - 9s 63ms/step - loss: 0.0340 - accuracy: 0.9889 - val_loss: 2.3741 - val_accuracy: 0.7592

# %%
show_plot(history_1D_LSTM, 'Embedding(Natasha) + Conv1D(20)x3 + LSTM(4)x2 + Dropout(0.2) + Dense(100)')

# %%
y_pred_lstm = model_Conv_LSTM.predict(x_test)
show_confusion_matrix(y_test, y_pred_lstm, CLASS_LIST_BALANCE)
# Out:
# 60/60 [==============================] - 3s 25ms/step
# Средняя точность распознавания:  77%

# %% [markdown]
# #### Итоги

# %% [markdown]
# В данном эксперименте мы использовали одни и те же данные в качестве проверочных и тестовых данных. Мы это сделали нарочно, чтобы данные в матрице ошибки характеризовали наши итоговые данные на проверочной выборке. По ним мы и сравним наши архитектуры. А также для того, чтобы в домашней работе вы аккуратно и последовательно разделили выборки и сделали все по правилам: обучили на обучающей выборке, контролировали ход обучения по проверочной выборке, а итоговую матрицу ошибок построили по тестовой выборке.
#
# Выпишем результаты средней точности распознования по матрице ошибок:
# 1. Embedding(Natasha) + SimpleRNN(10) + Dropout(0.3) - **19%**
# 2. Embedding(Natasha) + SimpleRNN(5) + Dropout(0.2)  - **20%**
# 3. Embedding(Natasha) + GRU(10) + Dropout(0.2) - **75%**
# 4. Embedding(Natasha) + GRU(40) + Dropout(0.2) - **86%**
# 5. Embedding(Natasha) + LSTM(20) + Dropout(0.2) - **83%**
# 6. Embedding(Natasha) + LSTM(100) + Dropout(0.3) - **83%**
# 7. Embedding(Natasha) + BLSTM(8)x2 + GRU(16)x2 + Dropout(0.3) + Dense(100) - **89%**
# 8. Embedding(Natasha) + Conv1D(20)x2 + Dropout(0.2) - **76%**
# 9. Embedding(Natasha) + Conv1D(20)x3 + LSTM(4)x2 + Dropout(0.2) + Dense(100) - **77%**
#
# Как и следовало ожидать результаты на простых SimpleRNN (1 и 2 эксперименты) получились неудовлетворительными, поэтому по возможности не используйте их. Причина такого "скромного" результата заключается в исчезающем градиенте, о котором мы говорили ранее.
#
# Вполне ожидаемо, что в нашем исследовании лучшей оказалась архитектура (7), использующая двухнаправленные LSTM сети в комбинации с GRU и полносвязанными сетями. Можете ее смело применять в своих проектах. Данная комбинация слоев была проверена на большом числе датасетов различных задач классификации текстов.
#
# Что неожиданно, но простая сверточная сеть (8 эксперимент), показала себя на уровне GRU (3 эксперимент)!
#
# В целом по GRU, LSTM и одномерным сверткам результаты получились похожими и зависимыми от числа нейронов в слое.
#
# Также вы можете самостоятельно проверить, что если мы не будем загружать в Эмбединги предварительно обученные веса из проекта Natasha, то потеряем по точности более 10%.

# %% [markdown]
# А теперь пора выполнить [домашнюю работу](https://colab.research.google.com/drive/1NMDG3ZeGgyHm0ei0DOC63PBb9rW6oN3O) с использованием наиболее понравившейся вам архитектурой, либо вы можете придумать свою.
